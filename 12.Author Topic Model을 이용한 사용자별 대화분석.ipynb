# %% [markdown]
# # LDA에서 Author Topic Model

# %% [markdown]
# <img src="figs/atm_fig.png">

# %% [markdown]
# * LDA에서 저자정보(metadata)가 추가된 토픽모델.
# * 문서별 단어분포를 반영하던 파라미터에, 저자별 문서분포 정보까지 추가된 형태.

# %% [markdown]
# <img src="figs/atm_fig2.png">

# %%
import pandas as pd
import numpy as np
from pprint import pprint

import pickle

# %%
with open("./cleaned_data.pk", "rb") as f:
    data = pickle.load(f)
    
data.reset_index(drop=True, inplace=True)
print(data.head())
print(data.info())
# Out:
#          Date   Speaker timetype   time contents
# 0  2021-06-14  김태환 형 17       오전   6:01      고민중
# 1  2021-06-14    이현직 16       오전   8:00      셤잘쳐
# 2  2021-06-14  김태환 형 17       오전   8:00      귀여워
# 3  2021-06-14  김태환 형 17       오전  10:07       시발
# 4  2021-06-14  김태환 형 17       오전  10:08   담배가 쓰다
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      980 non-null    object
#  1   Speaker   980 non-null    object
#  2   timetype  980 non-null    object
#  3   time      980 non-null    object
#  4   contents  980 non-null    object
# dtypes: object(5)
# memory usage: 38.4+ KB
# None

# %% [markdown]
# ### ATM 사용을 위한 데이터 처리

# %%
users = set(data["Speaker"])
users
# Out:
# {'김동현', '김락원 형 15', '김태환 형 17', '김표선 형 16', '이현직 16', '허정훈이 형 15'}

# %%
# 사용자별로 데이터 묶기
authors = data.groupby("Speaker")
pprint(authors.groups)
print(type(authors.groups))
# Out:
# {'김동현': Int64Index([102, 104, 135, 136, 148, 150, 152, 205, 206, 211, 212, 216, 239,
#             401, 402, 405, 406, 427, 431, 468, 470, 475, 476, 477, 482, 487,
#             488, 489, 492, 495, 498, 548, 584, 585, 586, 668, 669, 693, 701,
#             934, 960, 964, 973, 974],
#            dtype='int64'),
#  '김락원 형 15': Int64Index([  9,  28,  30,  33,  36,  46,  47, 100, 223, 225, 237, 380, 385,
#             389, 390, 398, 421, 424, 454, 465, 478, 505, 506, 536, 600, 603,
#             677, 684, 708, 712, 776, 779, 780, 785, 790, 792, 815, 818, 821,
#             825, 828, 830, 835, 840, 855, 858, 860, 890, 904, 918, 924, 927,
#             931, 935, 937, 941, 944, 947, 954, 957],
#            dtype='int64'),
#  '김태환 형 17': Int64Index([  0,   2,   3,   4,   6,   7,   8,  18,  26,  27,
#             ...
#             963, 965, 966, 967, 968, 969, 970, 975, 976, 977],
#            dtype='int64', length=317),
#  '김표선 형 16': Int64Index([ 12,  13,  20,  21,  22,  37,  43,  44,  45,  49,
#             ...
#             804, 805, 806, 817, 822, 861, 929, 930, 949, 950],
#            dtype='int64', length=250),
#  '이현직 16': Int64Index([  1,   5,  10,  11,  14,  15,  16,  17,  19,  23,  39, 254, 256,
#             278, 357, 358, 372, 397, 403, 404, 429, 432, 520, 523, 526, 529,
#             534, 535, 541, 542, 543, 676, 681, 683, 689, 718, 719, 720, 722,
#             769, 771, 807, 808, 809, 810, 811, 864, 870, 871, 872, 873, 874,
#             878, 879, 880, 888, 891, 892, 912, 971, 972, 978, 979],
#            dtype='int64'),
#  '허정훈이 형 15': Int64Index([ 24,  25,  41, 154, 157, 161, 162, 163, 164, 168,
#             ...
#             902, 903, 905, 906, 907, 913, 914, 915, 916, 917],
#            dtype='int64', length=246)}
# <class 'pandas.io.formats.printing.PrettyDict'>

# %%
# 묶인 데이터를 Int64Index에서 list로 바꾸기

author2doc = {}

for user, index in authors.groups.items():
    author2doc[user] = list(index)
    
print(author2doc)
# Out:
# {'김동현': [102, 104, 135, 136, 148, 150, 152, 205, 206, 211, 212, 216, 239, 401, 402, 405, 406, 427, 431, 468, 470, 475, 476, 477, 482, 487, 488, 489, 492, 495, 498, 548, 584, 585, 586, 668, 669, 693, 701, 934, 960, 964, 973, 974], '김락원 형 15': [9, 28, 30, 33, 36, 46, 47, 100, 223, 225, 237, 380, 385, 389, 390, 398, 421, 424, 454, 465, 478, 505, 506, 536, 600, 603, 677, 684, 708, 712, 776, 779, 780, 785, 790, 792, 815, 818, 821, 825, 828, 830, 835, 840, 855, 858, 860, 890, 904, 918, 924, 927, 931, 935, 937, 941, 944, 947, 954, 957], '김태환 형 17': [0, 2, 3, 4, 6, 7, 8, 18, 26, 27, 29, 31, 32, 34, 35, 38, 40, 42, 48, 50, 51, 53, 57, 61, 62, 63, 65, 66, 67, 68, 69, 70, 81, 82, 85, 87, 88, 89, 90, 93, 97, 99, 101, 103, 105, 113, 114, 118, 121, 126, 128, 137, 144, 158, 160, 165, 180, 182, 188, 191, 194, 199, 226, 232, 233, 235, 238, 241, 242, 247, 248, 252, 253, 255, 260, 264, 266, 269, 270, 271, 273, 279, 280, 282, 284, 288, 294, 296, 298, 300, 302, 303, 308, 312, 315, 320, 323, 324, 326, 329, 331, 333, 337, 338, 339, 345, 346, 348, 352, 354, 355, 359, 360, 364, 365, 367, 378, 379, 381, 382, 383, 384, 386, 387, 392, 393, 395, 396, 399, 409, 410, 414, 415, 417, 419, 420, 422, 423, 428, 436, 438, 440, 444, 445, 448, 455, 458, 461, 463, 479, 480, 485, 490, 491, 496, 497, 499, 501, 507, 510, 512, 513, 515, 518, 521, 527, 528, 545, 547, 549, 551, 557, 558, 560, 561, 562, 568, 570, 572, 574, 575, 577, 578, 582, 583, 587, 588, 589, 590, 592, 593, 595, 596, 597, 604, 605, 606, 609, 672, 673, 675, 678, 682, 686, 694, 696, 697, 700, 706, 707, 709, 713, 714, 715, 716, 717, 721, 723, 724, 727, 728, 729, 732, 733, 734, 739, 740, 741, 742, 745, 746, 747, 750, 751, 756, 757, 760, 761, 764, 765, 766, 767, 768, 770, 772, 775, 786, 791, 796, 800, 802, 812, 813, 814, 816, 847, 850, 853, 865, 866, 867, 868, 869, 875, 876, 877, 881, 882, 883, 884, 887, 893, 895, 898, 901, 908, 909, 910, 911, 919, 920, 921, 922, 923, 925, 926, 928, 932, 933, 936, 938, 939, 940, 942, 943, 945, 946, 948, 951, 952, 953, 955, 956, 958, 959, 961, 962, 963, 965, 966, 967, 968, 969, 970, 975, 976, 977], '김표선 형 16': [12, 13, 20, 21, 22, 37, 43, 44, 45, 49, 52, 54, 55, 56, 58, 59, 60, 64, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 83, 84, 86, 91, 92, 94, 95, 96, 98, 106, 107, 108, 109, 110, 111, 112, 115, 116, 117, 119, 120, 122, 123, 124, 125, 127, 129, 130, 131, 132, 133, 134, 138, 139, 140, 141, 142, 143, 145, 146, 147, 149, 151, 153, 155, 156, 159, 166, 167, 169, 172, 173, 175, 178, 179, 181, 183, 184, 185, 186, 187, 189, 190, 192, 193, 195, 196, 197, 198, 200, 202, 204, 207, 208, 209, 210, 213, 214, 215, 217, 218, 219, 220, 221, 222, 224, 231, 236, 249, 250, 251, 259, 267, 272, 274, 275, 276, 277, 281, 285, 286, 287, 289, 292, 295, 297, 301, 307, 309, 310, 311, 313, 314, 316, 317, 318, 319, 321, 322, 325, 327, 328, 330, 332, 335, 347, 368, 369, 370, 371, 374, 375, 376, 377, 433, 435, 449, 450, 453, 471, 472, 473, 474, 484, 493, 494, 569, 571, 610, 611, 612, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 630, 631, 635, 636, 638, 639, 641, 642, 647, 648, 649, 650, 653, 654, 655, 659, 660, 661, 663, 670, 671, 725, 726, 748, 749, 752, 753, 754, 755, 758, 759, 762, 763, 777, 778, 781, 782, 783, 784, 787, 788, 789, 793, 794, 795, 797, 798, 799, 801, 803, 804, 805, 806, 817, 822, 861, 929, 930, 949, 950], '이현직 16': [1, 5, 10, 11, 14, 15, 16, 17, 19, 23, 39, 254, 256, 278, 357, 358, 372, 397, 403, 404, 429, 432, 520, 523, 526, 529, 534, 535, 541, 542, 543, 676, 681, 683, 689, 718, 719, 720, 722, 769, 771, 807, 808, 809, 810, 811, 864, 870, 871, 872, 873, 874, 878, 879, 880, 888, 891, 892, 912, 971, 972, 978, 979], '허정훈이 형 15': [24, 25, 41, 154, 157, 161, 162, 163, 164, 168, 170, 171, 174, 176, 177, 201, 203, 227, 228, 229, 230, 234, 240, 243, 244, 245, 246, 257, 258, 261, 262, 263, 265, 268, 283, 290, 291, 293, 299, 304, 305, 306, 334, 336, 340, 341, 342, 343, 344, 349, 350, 351, 353, 356, 361, 362, 363, 366, 373, 388, 391, 394, 400, 407, 408, 411, 412, 413, 416, 418, 425, 426, 43 ...

# %%
# gensim의 들어갈 데이터 만들기

tokenized_data = [msg.split() for msg in list(data["contents"])]
print(tokenized_data[:10])
# Out:
# [['고민중'], ['셤잘쳐'], ['귀여워'], ['시발'], ['담배가', '쓰다'], ['왜'], ['담배가', '더', '쓰다'], ['락원아'], ['동현이가', '저녁', '먹으러', '오래'], ['오키오키']]

# %% [markdown]
# ### gensim을 이용한 Author Topic Model

# %%
from gensim.models import AuthorTopicModel
from gensim.corpora import Dictionary, bleicorpus
from gensim import corpora

import os
# Out:
# C:\Users\colin\anaconda3\envs\DH\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# ATM에 사용할 Dictionary 만들기
if not os.path.exists("kakao(ATM)_dict"):
    dictionary = corpora.Dictionary(tokenized_data)
    dictionary.save("kakao(ATM)_dict")
else:
    dictionary = Dictionary.load("kakao(ATM)_dict")
    
# ATM에 사용할 corpus 만들기
if not os.path.exists("kakao(ATM)_corpus"):
    corpus = [dictionary.doc2bow(doc) for doc in tokenized_data]
    corpora.BleiCorpus.serialize("kakao(ATM)_corpus", corpus)
else:
    corpus = bleicorpus.BleiCorpus("kakao(ATM)_corpus")

# %%
# ATM에 들어갈 데이터 확인하기
print("Number of authors : %d" % len(authors))
print("Number of unique tokens : %d" % len(dictionary))
print("Number of documents : %d" % len(corpus))
# Out:
# Number of authors : 6
# Number of unique tokens : 1793
# Number of documents : 980

# %%
# dictionary함수로 만든 사전에 있는 단어 보기
print(dictionary)
for idx in dictionary:
    print(dictionary[idx])
# Out:
# Dictionary(1793 unique tokens: ['고민중', '셤잘쳐', '귀여워', '시발', '담배가']...)
# 고민중
# 셤잘쳐
# 귀여워
# 시발
# 담배가
# 쓰다
# 왜
# 더
# 락원아
# 동현이가
# 먹으러
# 오래
# 저녁
# 오키오키
# 동현아
# 마른
# 어캐하냐
# 유지
# 체형
# 26년
# 동안
# 동현이처럼
# 생활하면
# 같은
# 동현이
# 될걸
# 체형이
# 동현이가아직
# 26년안했는데
# 생활을
# 혹시모르잖아
# 26년째되면
# 생활이지
# 정자생활도
# 나처럼
# 쟤도
# 찔지
# 음
# 보니깐
# 사륜안으로
# 안찐데
# 미래도봐지나
# 몇년
# 살았을
# 알고
# 정자가
# 줄
# 궁금한게
# 되냐
# 순환
# 어떻게
# 정자의
# 주기가
# 며칠
# 안갈걸
# 근데
# 동현이는
# 슈퍼
# 정자라
# 몇시에
# 저녁먹을거임
# 6시
# 5시45분
# 구체적인
# 매우
# 시각이
# 의심스러운데
# 지나치게
# 때문임
# 배드민턴
# 혹시
# 배고픔
# 아니
# 미안
# 아
# 감
# 당장
# 지금
# 도서관에서
# 오냐
# 뛰어라
# 뛰는중
# 그럼
# 나도
# 뜀
# 이거
# 풀어보셈
# 어케푸노
# 갖다대네
# 부분오픈을
# 정의는
# 정확한
# 호미오로
# 와
# 이게
# 풀이냐
# 똑똑하네
# 초딩들
# 위상도배우고
# 감사
# 답
# 뭐임
# 락교수
# 얼른
# 풀어
# 교환법칙
# 성립하냐
# 연산
# 저
# 몰라
# 같이
# 니
# 야
# 오늘
# 저녁먹었어야
# 표선아
# 했음
# 견제
# 락원이
# 씹오졌다
# 니가
# 안불러주는데
# 어케같이먹냐
# 섭섭하다
# 빤스런한건
# 아까
# 쳐불렀을때
# 내가
# 선약이
# 있었으니깐
# 실망이다
# 진짜
# 내일
# 점심
# 학식
# 선영이
# 있어서
# 깔깔깔
# 같았다
# 이현직
# 하지마
# 서태완이냐
# 쉣
# 홀리
# 무빙
# 잘못했네
# 살벌했음
# 공부
# 서로
# 쇼를
# 안했따
# 이러면서
# 하는데
# 내용
# 락원인
# 배우지도
# 않은
# 위상2
# 있고
# 다
# 동현인
# 족보
# 진작에
# 풀었고
# 벡해
# 나한테
# 몇문제
# 못풀었다했는데
# 편미방중간고사
# 100점만점에
# 88임
# 93
# 나
# 난
# 다풀었는데
# 싯팔
# 십점인데
# 한문제당
# 7점
# 감점이면
# 못풀어서
# 못푼거냐
# 기만
# 지리네
# 기만질
# 웃기네
# 존나
# 락원이도
# 만만치
# 않음
# 가는
# 거
# 락원이는
# 부터가
# 운동하러
# 기만질인
# 그리고
# 속보
# 하나
# 뭔데
# 거꾸로
# 나오느라
# 옷
# 입음
# 허겁지겁
# 뭐다
# 이말은
# 누군가
# 있었다
# 집에
# 여기까지
# 그건
# 그렇게
# 태환아
# 나오면
# 뒤집어서
# 보통
# 입지는
# 정상적으로
# 누가
# 않지
# 있다고
# 해서고
# 내밖에
# 없제
# 편
# 15
# 김락원
# 형
# 이제와서
# 중립이였지
# 항상
# 내리막길에
# 넣어놨찌
# 중립
# 이런반응이
# 정상이지
# 보네
# 숨통
# 트이나
# 교수님이
# 매기신듯
# 잘못
# 기만질은
# 어케
# 해명할건데
# 남았다
# 한참
# 또
# 가만보니
# 김태환이
# 문제네
# 근원인데
# 악의
# 이샛기
# 선동질
# 모함
# 비하
# 선동이라니
# 그런거
# 안해
# 어마어마한데
# 앞잡이느낌든거
# 나뿐이냐
# 배웠겠어
# 앞잡이
# 어디서
# 잡아서
# 허점
# 얘기하고
# 우리한테
# 동현
# 배운거지
# 선배한테
# 욕하자
# 봐봐
# 시작이네
# 많은데
# 문제가
# 선배들이
# 이샛깈
# 어떡하겠노
# 떠넘기기까지
# 이렇게
# 태환
# 국회의원해라
# 직업
# 찾았다
# 가면
# 거기
# 성공한다
# 맨날
# 자기는
# 잘못없고
# 때문이라함
# 사람
# 옆에
# 안하잖아
# 웃긴건뭔지암
# 놀리기만
# 살짝
# 처음에
# 하고
# 옆사람한테
# 바통넘겨즈고
# 뒤에서
# 웃고만
# 있음
# 지는
# 뭐라하면
# 피해자가
# 정곡을
# 찔리네
# 아무것도
# 안했어
# 웃기만했어
# 시전
# 간신
# 샵검색
# 떠넘기기
# 바로
# 옆사람
# 태환이형
# 그
# 누군지암
# 옆사람이
# 여기
# 출연했다매
# 허정훈
# 새로
# 옷을
# 입었냐가
# 중요하지
# 정훈
# 조합
# 아찔한데이겈
# 갑자기
# 공격
# 나는
# 받은거냐
# 놀린게
# 동현이까지
# 실수였나보네
# 이번에
# 다르긴
# 밖에서
# 옷이랑
# 입는
# 집에서
# 함
# 다음번엔
# 잘나눠야겠노
# 팀
# 늘
# 운동복만
# 입고
# 있어
# 넌
# 모르네
# 아직도
# 잘
# 친구를
# 쉿
# 받아야해
# 실망감
# 좀
# 실망한거였냐
# 글지
# 홀리몰리
# 뎀쓌
# 오늘은
# 쨋든
# 하
# 시험기간
# 재밌었다
# 공방전이
# 동현이의
# 락원이와
# 치열한
# 니덕에
# 멋있었다
# 궁금함
# 이길지
# 조금
# 느꼈는데
# 생파때
# 저번에
# 조만간
# 10프로였음로
# 락원이한테
# 선동한건
# 신고함
# 학교폭력으로
# 적었다
# 서포팅
# 해주는데
# 않네
# 읽지도
# 카톡을
# 다담즈에
# 풀빌라가는데
# 1박
# 2인
# 43만원나옴
# 비싸긴하더라
# 비싸네
# 목금
# 잡았는데도
# 43만원임
# 그러면
# 금요일에
# 보겠네
# 오
# 잘하면
# 송정인데
# 서핑함
# 송정에서
# 락데이트날임
# 마린케이풀빌라
# 부산
# 여기임
# 이쁘지않냐
# 5주년기념
# 데이트하러감
# 5365
# 머리로
# 참았다
# 해보려다가
# 김태환
# 선영이한테
# 1825
# 천몇백일
# 축하한다했은데
# 2로
# 된다이가
# 하면
# 1800일
# 이미
# 지났다고
# 하니깐
# 일하는데
# 친구
# 포항
# 풀빌라애서
# 수
# 있는데
# 할인해달라고
# 해줄
# 1900일
# 곧
# 오잖아
# 개인
# 거기도
# 수영장
# 사이트
# 알려줄스있음
# 주소
# 마치블루
# 많이
# 온다
# 유명인들
# 돈이업다
# 73만원
# 좋은방아니가
# 기본방임
# 수영장있는거
# 넓긴하네
# 방자체가
# 보내준거는
# 이쁘기도
# 교통이
# 너무비싸고
# 아깝누
# 공부하고
# 왔더니
# 카톡
# 핫하네
# 락원
# 오랜만에
# 편들어줬다
# 내편이
# 정상인거지
# 이걸
# 찌르네
# 선영이도
# 꼽주는거
# 어디가서
# 안밀린다니까
# 매력포인트지
# 잘못뒀다
# 집부
# 네
# 편이야
# 사이에
# 어딨냐;;
# 편이
# 93점
# 드리겠습니다
# 명언
# 점수
# 락원이를
# 말하는거지
# 생각
# 안하니깐
# 저렇게
# 친구로
# 태환이는
# 이거에
# 줘야지
# 88점
# 있나
# 작년에
# 표햄
# 푼거
# 가노
# 왤케
# 일찍
# 6시반에
# 왔다
# 피곤쓰
# 엥
# 도착했는데
# 되는거임
# 시험
# 잘쳐
# 말안해도
# 잘치겠지만
# 공부안해도
# 나오더라
# 에이제로는
# 라고
# 말함
# 이건
# 팩트임
# 말하니깐
# 보이긴
# 선동처럼
# 맞음
# 실상은
# 팩트
# 안나오던데
# 이현직이네
# 사칭아니긴함
# 너무
# 도서관
# 추운데
# 온도
# 올려야하나
# 공소지하오면
# 끝나면
# 나올게
# 데리고
# 락새끼
# 먹을래
# 날도
# 뚜뚜주
# 뜨끈한
# 이근
# 두근두근
# 메뉴
# 문제있숴
# 어디임
# 태디
# 공소도착3분전
# 이건찐
# 지하에서보자
# 표
# 옥상이나챠와
# 옥상임
# 꺼져
# 길다
# 팔
# 닿이겠는데
# 무릎
# 손가락피면
# 이네
# 직섹시
# 앞
# 안불러주냐
# 삼각김밥아
# 머리
# 현직이
# 배신
# 좆되더라
# 먹으려고
# 삼각김밥
# 저녁에
# 사둔건데
# 니랑
# 먹을려고
# 했는데
# 나와
# 라고하면
# 응
# 이럴거잖아
# 서운하다진짜
# 씨발련아
# 에이
# 개샛기로
# 니는
# 보노
# 두말하겠나
# 표선이가
# 한입으로
# 그런
# 닌
# 보냐
# 사과해라
# 사과
# 이정도면
# 할거
# 했지
# 같이나와
# 락데리고
# 시험칠거임
# 점심안먹고
# 련아
# 죽어
# 일단
# 표선이
# 락원이보다
# 심했다
# 락밑표
# 먼저
# 버림
# 태환이가
# 가겠네
# 밑으로도
# 있으면
# 직이
# 공부하러
# 나랑같이
# 온다해넣고
# 도서관으로
# 튐
# 그런적
# 없음
# 나랑
# 만나고
# 2분뒤에
# 거짓말인거
# 아시죠
# 여러분
# 놑열
# 어
# 열렸다
# 빠이
# 가버림
# 진짜;
# 쌍방
# 이번건
# 사온거지
# 삼김을
# 예상하고
# 일방임
# 너가
# 벌레짓해서
# 한거지
# 사
# 산거지
# 그래서
# 그런거지
# 뛰어나다고
# 봐야하는거지
# 준비성이
# 얘기가
# 중요한
# 대박이네
# 공부안했다몀서
# 개쩐다
# 왜케
# 있노
# 연막
# 이틀이가
# 하루
# 그니간
# 속는
# 흑우
# 그래도
# 믿어봤는데
# 속았네
# 에쿠
# 껄껄
# 안되겠다
# 13년
# 니한테
# 뒤
# 사기침
# 정확히
# 당해주셈
# 사기는
# 아니고
# 아니지
# 보증
# 부탁함
# 서달라고
# 13년뒤까지
# 연락하면
# 보증정도는
# 서주지
# 돈
# 빌려줘
# 채우고와
# 쒸팔
# 몇시간이야
# 시험이
# 힘들다
# 연막충
# 김락원이랑
# 끝까지
# 남아있는거아님
# 동현이만
# 류지까지
# 남았때
# 셋
# 개빡치네
# 류지
# 아직
# 좋아함
# 락원이한테서
# 모습이
# 보였음
# 오늘보니깐
# 태성이
# 아기
# 태성임
# 성인까지는
# 어마무시하던데
# 뒤져따
# 이따
# 카페에서
# 설사를
# 하지
# 다음학기
# 확통
# 이미경교수님이래
# 괜찮을듯
# 락투
# 개씹쌉꿀이고
# 방금김상일교수님만났는데
# 2학기
# 확통하냐고물어보니깐
# 이미경교수님이하신다함
# 확통은
# 김상일교수님
# 해석2하신데
# 개꿀이네
# 김상일이면
# 해석
# 꿀이지
# 솔직히
# 신기연만
# 안오면
# 개꿀인데
# 미루길
# 잘했네
# 시험은
# 어땠음
# 이번
# 조졌나
# 굳이
# 비도
# 와서
# 치지말자
# 흐린데
# 그냥
# 그럭저럭
# 친듯
# 풀었네
# 고생했다
# 카페가나
# 친게
# 푼게
# 각자
# 비오는데
# 하자
# 부정적이야
# 애가
# 상처
# 처상
# 상처받아도
# 알겠다고
# 친구가
# 5번째
# 만들기로
# 썸
# 어떻게되는건데
# 우리
# 한건
# 반할만하너
# 공감해주라고
# 상처받으면
# 하잖아
# 공감
# 무시해
# 안하고
# 종강
# 수학과
# 이제
# 졸업이다
# 고생했노
# 돼지
# 고맙다
# 멸치
# 나가지마라
# 현직아
# 날아간다
# 바람에
# 정훈아
# 드디어
# 락원이가
# 연락이
# 왔음
# 저녁먹자고
# 농담하지마셈
# 꿈꾸는거
# 아님
# 아아니야
# 그랬단
# 말이야
# 치킨
# 안먹
# 닭
# 땡기면
# 먹고오셈
# 됨
# 안먹어도
# 하마
# 매좋
# 몇시
# 매좆
# 패고싶네
# 비
# 옴
# 개빨리뜨네
# 성적
# 편미방
# 까자
# 97
# 138
# 살빠졌네
# 97키로이고싶다
# 버로나오메
# 0이
# 100는
# 몇개
# 있을까
# 100
# 두개있네
# 여기엔
# 6×424
# 예
# 5의
# 갯수만큼
# 소인수분해
# 있을테니깐
# 했을때
# 캬
# 대강
# 부근일걸
# 니도
# 역시
# 괴물은
# 괴물이다
# 24개임
# 실제로
# 락앞에서
# 부끄럽다
# 조용히
# 해
# 말
# 아는데
# 안하는중
# 몇초만에
# 볼라고
# 푸는지
# 내
# 답은
# 무시하냐
# 앞으로
# 해야한디
# 재능이지
# 무시하네
# 한
# 11시까지
# 복기문
# 제출해
# 공평하게
# 내기를
# 동전이
# 때
# 맞추는
# 앞뒤를
# 찌그러져있을
# 하려면
# 해야해
# 꼭
# 숙제
# 해라
# 11시야
# 5분이면
# 안다
# 이거는
# 읽은거
# 충분하제
# 동전
# 성의없는
# 소리
# 이딴
# 펴야지
# 하지말자
# 내기할꺼임
# 너네
# 있는
# 찌그러트려서
# 채
# 다시
# 펴줄게
# 뭐라
# 설렌다
# 얘기할지
# 다르지
# 따라
# 않나
# 찌그러져있는지에
# 찌그러져있더라도
# 동일하게
# 하고자한다면
# 개가기싫네
# 새도
# p를
# 때의
# 모름
# 확률
# 올걸
# 짐들고
# 기만질이냐
# 시험다끝났는데
# 짐가지러가기귀찮다고하는건
# 갈라고
# 왔는데
# 짐두고
# 비가
# 안그치네
# 같은데
# 아닌거
# 통계문제가
# 빨리와
# 거의
# 살면서
# 없어
# 통계문제는
# 가장
# 잘하는
# 창의수리지
# 통계문제라기보다
# 기만이지
# 역겹다
# 기말15등아면
# 에이쁠안되는거아니냨
# 글입니다
# 내려주세요
# 모르고
# 올린
# 제
# 30프로까지
# 되긋니
# 에이인데
# 되긋지
# 담타
# 방금하고
# 왔는뎅
# 30분에
# 갈게
# 9시까디
# 갔다가
# 부산대역
# 비안오면
# 출발해
# 2분
# 나갈게
# 뒤에
# 출발할게
# 나옴
# 나갔노
# 내버리고
# 기다리는중임
# 언제
# 풀어주노
# 떨리면서
# 부랄
# 기다리는
# 중인데
# 모르겠는데
# 저거
# 물어봐
# 태환이한테
# 모르는걸
# 알리가
# 톡방의
# 희망
# 김락1
# 대답을
# 창의적인
# 해줘
# 1
# lemma로
# 가하면
# 무게중심이
# 물리적인
# 변했으니깐
# 안되는거까지
# 임의로
# 줄게
# 찌그러
# 트렸으면
# 힘을
# 둘
# 제출해줘
# 시험임
# 문제
# 보고서랑
# 두개
# 제출이네
# 락1이
# 못해;;
# 밖에
# 저건
# 2
# 락
# 락12
# 0락2한테
# 물어봐도
# 봐줌
# 락풍년이고
# 수학과에
# 관심
# 받아서
# 좋겠다
# 떨리는
# 랄부
# 부러워서
# 중
# 대신
# 떠는
# 맞게
# 비트에
# 락풍년
# 우리과
# 지상락원이지
# 와시발
# 싶은데
# 이기고
# 찢었다
# 한다
# 시험이야
# 농담도
# 뭐랄까
# 저거는
# 식히기
# 정도다이가
# 배드민턴칠때
# 머리많이쓰니까
# 식히는군
# 저런식으로
# 한340분뒤
# 빨끝내라
# 똥부터
# 싸고
# 얍
# 78사이
# 교육받는
# 프로그램에서
# 기초
# 파이썬
# 하라고
# 듣는데
# 수업
# 여기서
# 들으셈
# 마스터인가
# 좆밥이지
# ptj를
# 견딘
# 남잔데
# 그러던지
# 다음주에
# 들어야지
# 갠톡으로
# 줄수
# 아니다
# 하면되지
# 그거
# 꾹
# 눌러서
# 나에게
# 누르면
# 버튼
# 카톡으로
# 굉장히
# 알아두셈
# 유용하니까
# 락원이랑
# 모르는거
# 물어봐라
# 스터디하고
# 다음주
# 스터디
# 하실
# 3일이면
# 떡을치지
# 공소
# 몇시에올거임
# 안팎
# 한2시
# 락3떡;;
# 21
# 22
# 23일
# 23일에
# 마무으리
# 병원에서
# 미쳤따
# 기억하제
# 알바도
# 까먹었음
# 28일이였나
# 간다
# 형은
# 보자
# 28일
# 6월
# 병원
# 알바
# 잘가라잉
# 먼저갈게
# 못
# 버티겠다
# 공지
# 톡게시판
# 아시발
# 님들
# 1분만
# 라스트찍노
# 짐정리
# 할게
# 그럴순
# 없다
# 1층에서
# 기다림
# 꼴찌
# 제출
# 했나
# 늦네
# 쪼금
# 감점
# 되는데
# 씨게
# 누움
# 잘려고
# 그전에
# 락1아
# 제출해야지
# 자야돼
# 12시까지는
# 제출하자
# 너의
# 답이
# 듣고싶어
# 아이패드
# 추천
# 가격대와
# 승능
# 즉당한
# 먹혀있다
# 자리
# 사셈
# 에어
# 가성비갑임
# 에어가
# Air
# 장점이
# 가성비
# 개씹가성비임
# 갑
# 요새
# 프로보다는
# 아이패드가
# 기본
# 프로
# 있거든
# 미니
# 새로나오면서
# 가격은
# 비슷한
# 성능인데
# 프로랑
# 훨씬삼
# 쌈
# 고
# 에어랑
# 펜이랑
# 사면
# 온라인에서
# 학생할인으로
# 가격비교해봐야함
# 갓팡도
# 싸거든
# 킹짱팡
# 오호
# 거기서
# 하는구만
# 할인도
# 갓팡이랑
# 교육스토어랑
# 애플
# 엉엉
# 복지스토어
# 3개확인해야함
# 이모티콘
# 내기억으로
# 갓팡이
# 애플펜슬은
# 제일
# 따로
# 사야하노
# 펜슬은
# 2세대가
# 기본쓰제
# 2세대임
# 사라는거
# 2세대얐거든
# 원래
# 프로만
# 2세대로
# 나온
# 알고있음
# 에어4도
# 거기에
# 지문인식가능
# 와저래
# 크노
# 공부용으로
# 사는거맞제
# 인강용이아니라
# 내가말한공부용은
# 필기하는거
# 엄
# 강의도
# 들을듯
# 못듣나
# 에어로는
# 이
# 쓸려면
# 인강용으로만
# 딴거사라고
# 말거
# 할랬지
# 어떤거
# 갤탭같은거
# 으이
# 비교
# 해봐야겠네
# 갤탭은
# 되게
# 들었는데
# 안좋다고
# 아닌가베
# 요샌
# 괜찮다고
# 들었어요
# 아이패드져
# 방학
# 방학이다
# 짱깨
# with
# 나쁘지않지
# 약속있어
# 락속
# 에반데
# NN
# With
# nn
# 락녀
# 새로운
# 인증해버리자너
# 일편단심
# 해바라기
# 가자
# 허
# 가김
# 도서관와서
# 쳐먹는거뿐이네
# 하는게
# 니꺼까지
# 시키께
# 짜장으로
# 잘있어
# 태환이
# 담
# 태담태담
# 가버렸노
# 걍
# 암
# 홈
# 일정
# 있었어서
# 비온디
# 데이트가고
# 우리는
# 도서관가네
# 졸업하고
# 운동감
# 취집간대잖아
# 운동간다고
# 우리랑
# 카페가야지
# 안가지
# 카페는
# 우같카
# 합격
# 갔는데
# 들었다
# 마스크
# 쓰고
# 영락이
# 유식이형한테도
# 이름
# 형이
# 기대해도
# 되겠지
# 쁠
# 담주
# 직
# 화
# 깨우셈
# 우리집온나
# 밥해줌
# 교수님
# 김세라
# 되심
# 박사님
# 수학
# 해군사관학교
# 굿
# 17점이나오지
# 30점만점에
# takehome
# 시험인데
# 위상
# 평균이
# 구글링도
# 놈들이
# 던지는
# 있네
# 허용인데
# 17점이면
# 잘나온거아니냐
# 강의노트
# 구글이랑
# 나오는데
# 반
# 보면
# 이상은
# 모기한테
# 물림
# 엉덩이
# 꺼지라
# 썅년
# 프레드릭소렌드
# 취소함
# 개같은련이
# 과제내고
# 매일
# 강제로
# 사게하잖아
# 책
# 책은
# 굴리고
# 중고로
# 들으세
# 그따구임
# 대실영은
# 구할려고
# 사야한데
# 새책
# 입력해서
# 좆지랄해야하는데
# 책에
# 코드
# 그러더라
# 못한다고
# 똑같음
# 새끼들
# 웬만한
# 듣는게
# 들을
# 속
# 있을
# 편함
# 가야지
# 안고
# 대실영따위가
# 일게
# 일개
# 탭스한다건
# 어디갔냐
# 땄음
# 영어
# 졸업영어는
# 대실영도
# 되는거
# 면제
# 몇점나옴
# 탭스
# 17부턴
# 텝스
# 토플
# 76
# 다시보게
# 땜에
# 라이팅
# 스피킹이랑
# 토익변환라면
# 몇점나오는거임
# 어차피
# 올릴거라
# 재시험쳐서
# 그때
# 내려고
# 낼
# 영역별로
# 최고점수
# 토플은
# 결석했넴
# 계절
# 아씨
# 히힛
# 그는
# 쳤다
# 딸을
# 가졌으면
# 건전한
# 사상을
# 좋겠어
# 도
# 서관
# 자주있네
# 저녁약속
# 바쁜
# 사람이지
# 술마셔야지
# 시험끝났는데
# 부산감
# 이번주
# 일요일에
# 지금대구임
# 동영상
# 귀여운뽀또보는중
# 그면
# 술
# 월요일
# 얼굴보기
# 연애하더니
# 힘들어짐
# 몇일인지
# 모르겠지만
# 5주년임
# 봤던거
# 어제
# 기억
# 안나
# 오래됐네
# 졸라
# 7월12
# 놀러가거든
# 술마실래
# 월화
# 중에
# 선영아
# 졸업
# 축하한다
# 선영이인데
# 그만해
# 너
# 일베좀
# 하자며
# 조용하라고
# 했잖아
# 쉽지않네
# 시간되냐
# 5인이상
# 풀리지않음
# 7월1일부터인가
# 오늘부터
# 8인임
# 붓산
# 5인이상때매
# 누구생일인데
# 안간다
# 불허
# 이런거
# 월욜부터
# 토욜까지
# 풀약
# 생일로
# 7시까지
# 다들
# 락원이네집으로
# 집합
# 7시에는
# 집에없다
# 뺀다고
# 귀엽게자지않냐
# 안불편한가
# 저러면
# 누나
# 뭐
# 앞에서는
# 저러는데
# 시비냐
# 아침부터
# 자주
# 잠
# 뜻이지;;
# 보고싶다는
# 시비라니
# 오점몇
# 11시45분
# 나왔는데
# 먹고
# 방금
# 코코볼
# 홀리쒯
# 1230어떤데
# 1시에
# 안됨
# 운동가야해서
# 그럴거야
# 끝나자마자
# 끝났으니
# 운동가야지
# 때는
# 시험기간일
# 안간척하냐
# 1210
# 운동갈꺼
# 챙겨오셈
# 11시50
# 1200
# 양보했다
# 15분
# 30분
# 12시
# 17
# 건방지게
# 대답이
# 없노
# 기절했나
# 북문
# 라인
# 밥집
# 개판이네
# 학교
# 아니제
# 지각하는거
# 와이
# 공부하는거
# 구글
# 미트로
# 병원가거나
# 아니면
# 하자는데
# 어느게
# 좋노
# 미트는
# 줌이랑
# 거임
# 똑같은
# 굳
# 좋아하는걸로
# 미트
# 3시간동안
# 누른다
# 라임빌에서
# 벨
# 안들으면
# 양보했는데
# 이정도
# 강요지
# 아니라
# 양보가
# 끝나고
# 연락
# 줘
# 헬쓰
# 끝났지
# 헬스는
# 만들어서
# 치냐
# 밥이신갑네
# 가서
# 끼부리나보지
# 돌싱아줌마들한테
# 꺄르륵
# 락원학생
# 엉덩이봐
# 튼실하네
# 응디
# 한번
# 흔들어봐라
# 정없네
# 그런거없나
# 에타
# 그니까
# 17김태환형
# 어떰
# 이틀딱
# 저장해줬는데
# 애정넘치네
# 수정함
# 김일페
# 로
# 임팩트가
# 강한거로
# 볼자노무현
# 낫네
# 현재까진
# 나도저거함
# 링크
# 보내줄게
# 출근해서
# 돼
# 안보내줘도
# 보내주고
# 후회해
# 일단보내줘
# 미방
# 있는사람
# 한국어책
# 먹음
# 에
# 개빨리
# 먹노
# 먹었더니
# 배고프네
# 약하노
# 몇시까지
# 하노
# 10시
# 50분
# 온대
# 이샛기는
# 이럴떄만
# 답장이
# 빠르네
# 알바임
# 어메이징한데
# 속도봐라1
# 됐으면서도
# 약속
# 취소
# 없이
# 일언반구
# 쳐갔다는데
# 교육
# 못하겠음;;;
# 통화를
# 혈압올라서
# 미뤄진거지
# 취소가
# 막나가겠다는거야
# 실망인데
# 님스
# 떨어짐
# 탈
# 해버렸습니다
# 쏴야지
# 위로겸
# 한턱
# 위로만
# 해줄게
# 밥으로
# 위로는
# 자기
# 잘해서
# 훨씬
# 내게
# 밥
# 사는것을
# 허락하지
# 거절할게
# 허락해
# 고토
# 비쁠
# 만족한다
# 비쁠은
# 잘한거지
# 살게
# 어이스크림
# 까라
# 빨리
# 사줘라
# 이번주는
# 집감
# 동한테
# 고기
# 못얻어먹네
# 개조진게
# 기말
# 큰거같은데
# A0로
# 먹는거보다는
# 못얻어
# 못보고
# 전체평점도
# 교양을
# 끝나서
# 다행임
# 생각들다가도
# 쳐들었지
# 학기중에
# 교필은
# 들은거임
# 교선까지
# 끝남
# 이번계절로
# 6학점
# 끝이다
# 후
# 대면이라던데
# 재강
# 피셜로
# 호균
# 같기도
# 그런것
# 뉴스보니깐
# 거지같네
# 어떡하냐
# 대면
# 자신이
# 가야되는데
# 그시간에
# 헬스
# 완전창남인데
# 창남이긴
# 헬창도
# 14시
# 근무
# 수욜
# 계절수업있어서
# 과외랑
# 멘토링이랑
# 오후시간대
# 912시로
# 월
# 했는뎅
# 1등
# 팽방
# 개띄꺼운데
# 나한텐
# 안해주냐
# 인사
# 생각났다
# 아이디어
# 지리는
# 게임방식
# 롤
# 방식이나
# 이런걸로
# 채팅
# 플레이
# 분석
# 잼민이
# 씨발
# 오바잖아
# 학원가는건
# 아닌지
# 잼민이인지
# 판단해달라는거
# 게임이탈여부
# 알고리즘
# 예측
# 이런건
# 아닌지를
# 알고싶어
# 잼민인인지
# 닷지하게
# 많으면
# 픽창에서
# 쓰발
# 잼민이뱃지
# 이런거있음좋겧다

# %%
# 사람이 이해할 수 있는 형태로 코퍼스 사전 재구성 해보기 (term-frequency)
# for cp in corpus:
#     print(cp)
    
[[(dictionary[id], freq) for id, freq in cp] for cp in corpus]
# Out:
# [[('고민중', 1.0)],
#  [('셤잘쳐', 1.0)],
#  [('귀여워', 1.0)],
#  [('시발', 1.0)],
#  [('담배가', 1.0), ('쓰다', 1.0)],
#  [('왜', 1.0)],
#  [('담배가', 1.0), ('쓰다', 1.0), ('더', 1.0)],
#  [('락원아', 1.0)],
#  [('동현이가', 1.0), ('먹으러', 1.0), ('오래', 1.0), ('저녁', 1.0)],
#  [('오키오키', 1.0)],
#  [('동현아', 1.0)],
#  [('마른', 1.0), ('어캐하냐', 1.0), ('유지', 1.0), ('체형', 1.0)],
#  [('26년', 1.0), ('동안', 1.0), ('동현이처럼', 1.0), ('생활하면', 1.0)],
#  [('같은', 1.0), ('동현이', 1.0), ('될걸', 1.0), ('체형이', 1.0)],
#  [('동현이가아직', 1.0)],
#  [('26년안했는데', 1.0), ('생활을', 1.0)],
#  [('혹시모르잖아', 1.0)],
#  [('26년째되면', 1.0)],
#  [('생활이지', 1.0), ('정자생활도', 1.0)],
#  [('나처럼', 1.0), ('쟤도', 1.0), ('찔지', 1.0)],
#  [('음', 1.0)],
#  [('보니깐', 1.0), ('사륜안으로', 1.0)],
#  [('안찐데', 1.0)],
#  [('미래도봐지나', 1.0)],
#  [('몇년', 1.0), ('살았을', 1.0), ('알고', 1.0), ('정자가', 1.0), ('줄', 1.0)],
#  [('궁금한게', 1.0),
#   ('되냐', 1.0),
#   ('순환', 1.0),
#   ('어떻게', 1.0),
#   ('정자의', 1.0),
#   ('주기가', 1.0)],
#  [('며칠', 1.0), ('안갈걸', 1.0)],
#  [('근데', 1.0), ('동현이는', 1.0), ('슈퍼', 1.0), ('정자라', 1.0)],
#  [('몇시에', 1.0), ('저녁먹을거임', 1.0)],
#  [('6시', 1.0)],
#  [('5시45분', 1.0)],
#  [('구체적인', 1.0), ('매우', 1.0), ('시각이', 1.0), ('의심스러운데', 1.0), ('지나치게', 1.0)],
#  [('때문임', 1.0), ('배드민턴', 1.0), ('혹시', 1.0)],
#  [('배고픔', 1.0), ('아니', 1.0)],
#  [('미안', 1.0), ('아', 1.0)],
#  [('감', 1.0), ('당장', 1.0), ('지금', 1.0)],
#  [('도서관에서', 1.0), ('오냐', 1.0)],
#  [('뛰어라', 1.0)],
#  [('뛰는중', 1.0)],
#  [('그럼', 1.0), ('나도', 1.0), ('뜀', 1.0)],
#  [('이거', 1.0), ('풀어보셈', 1.0)],
#  [('어케푸노', 1.0)],
#  [('갖다대네', 1.0), ('부분오픈을', 1.0), ('정의는', 1.0), ('정확한', 1.0), ('호미오로', 1.0)],
#  [('와', 1.0), ('이게', 1.0), ('풀이냐', 1.0)],
#  [('똑똑하네', 1.0), ('초딩들', 1.0)],
#  [('위상도배우고', 1.0)],
#  [('감사', 1.0)],
#  [('이거', 1.0), ('답', 1.0), ('뭐임', 1.0)],
#  [('락교수', 1.0), ('얼른', 1.0), ('풀어', 1.0)],
#  [('교환법칙', 1.0), ('성립하냐', 1.0), ('연산', 1.0), ('저', 1.0)],
#  [('나도', 1.0), ('몰라', 1.0)],
#  [('같이', 1.0),
#   ('니', 1.0),
#   ('야', 1.0),
#   ('오늘', 1.0),
#   ('저녁먹었어야', 1.0),
#   ('표선아', 1.0),
#   ('했음', 1.0)],
#  [('왜', 1.0)],
#  [('동현이', 1.0), ('견제', 1.0), ('락원이', 1.0), ('씹오졌다', 1.0)],
#  [('니가', 1.0), ('안불러주는데', 1.0)],
#  [('어케같이먹냐', 1.0)],
#  [('섭섭하다', 1.0)],
#  [('니', 1.0), ('빤스런한건', 1.0), ('아까', 1.0), ('쳐불렀을때', 1.0)],
#  [('내가', 1.0), ('선약이', 1.0), ('있었으니깐', 1.0)],
#  [('실망이다', 1.0), ('진짜', 1.0)],
#  [('내일', 1.0), ('점심', 1.0), ('학식', 1.0)],
#  [('미안', 1.0), ('내가', 1.0), ('내일', 1.0), ('선영이', 1.0), ('있어서', 1.0)],
#  [('깔깔깔', 1.0)],
#  [('같았다', 1.0), ('이현직', 1.0), ('하지마', 1.0)],
#  [('진짜', 1.0), ('서태완이냐', 1.0)],
#  [('쉣', 1.0), ('홀리', 1.0)],
#  [('무빙', 1.0), ('잘못했네', 1.0)],
#  [('근데', 1.0), ('아', 1.0), ('아까', 1.0), ('진짜', 1.0), ('살벌했음', 1.0)],
#  [('더', 1.0),
#   ('동현이', 1.0),
#   ('락원이', 1.0),
#   ('공부', 1.0),
#   ('서로', 1.0),
#   ('쇼를', 1.0),
#   ('안했따', 1.0),
#   ('이러면서', 1.0),
#   ('하는데', 1.0)],
#  [('알고', 1.0),
#   ('내용', 1.0),
#   ('락원인', 1.0),
#   ('배우지도', 1.0),
#   ('않은', 1.0),
#   ('위상2', 1.0),
#   ('있고', 1.0)],
#  [('다', 1.0), ('동현인', 1.0), ('족보', 1.0), ('진작에', 1.0), ('풀었고', 1.0)],
#  [('벡해', 1.0)],
#  [('동현이', 1.0), ('나한테', 1.0)],
#  [('몇문제', 1.0), ('못풀었다했는데', 1.0), ('편미방중간고사', 1.0)],
#  [('100점만점에', 1.0)],
#  [('동현이', 1.0), ('88임', 1.0), ('93', 1.0), ('나', 1.0)],
#  [('난', 1.0), ('다풀었는데', 1.0), ('싯팔', 1.0)],
#  [('십점인데', 1.0), ('한문제당', 1.0)],
#  [('몇문제', 1.0), ('7점', 1.0), ('감점이면', 1.0), ('못풀어서', 1.0)],
#  [('몇문제', 1.0), ('난', 1.0), ('못푼거냐', 1.0)],
#  [('동현이', 1.0), ('기만', 1.0), ('지리네', 1.0)],
#  [('아', 1.0), ('기만질', 1.0), ('웃기네', 1.0), ('존나', 1.0)],
#  [('락원이도', 1.0), ('만만치', 1.0), ('않음', 1.0)],
#  [('가는', 1.0), ('거', 1.0), ('락원이는', 1.0), ('부터가', 1.0), ('운동하러', 1.0)],
#  [('기만질인', 1.0)],
#  [('더', 1.0), ('아', 1.0), ('그리고', 1.0), ('속보', 1.0), ('하나', 1.0)],
#  [('뭔데', 1.0)],
#  [('오늘', 1.0),
#   ('락원이', 1.0),
#   ('거꾸로', 1.0),
#   ('나오느라', 1.0),
#   ('옷', 1.0),
#   ('입음', 1.0),
#   ('허겁지겁', 1.0)],
#  [('뭐다', 1.0), ('이말은', 1.0)],
#  [('누군가', 1.0), ('있었다', 1.0), ('집에', 1.0)],
#  [('여기까지', 1.0)],
#  [('왜', 1.0), ('되냐', 1.0), ('그건', 1.0), ('그렇게', 1.0)],
#  [('진짜', 1.0), ('태환아', 1.0)],
#  [('않음', 1.0),
#   ('옷', 1.0),
#   ('나오면', 1.0),
#   ('뒤집어서', 1.0),
#   ('보통', 1.0),
#   ('입지는', 1.0),
#   ('정상적으로', 1.0)],
#  [('옷', 1.0),
#   ('집에', 1.0),
#   ('뒤집어서', 1.0),
#   ('입지는', 1.0),
#   ('누가', 1.0),
#   ('않지', 1.0),
#   ('있다고', 1.0),
#   ('해서고', 1.0)],
#  [('락원아', 1.0),
#   ('니', 1.0),
#   ('진짜', 1.0),
#   ('내밖에', 1.0),
#   ('없제', 1.0),
#   ('편', 1.0)],
#  [('15', 1.0), ('김락원', 1.0), ('형', 1.0)],
#  [('이제와서', 1.0)],
#  [('난', 1.0), ('중립이였지', 1.0), ('항상', 1.0)],
#  [('내리막길에', 1.0), ('넣어놨찌', 1.0), ('중립', 1.0)],
#  [('이런반응이', 1.0), ('정상이지', 1.0)],
#  [('락원이', 1.0), ('보네', 1.0), ('숨통', 1.0), ('트이나', 1.0)],
#  [('교수님이', 1.0), ('매기신듯', 1.0), ('잘못', 1.0)],
#  [('그럼', 1.0), ('기만질은', 1.0), ('어케', 1.0), ('해명할건데', 1.0)],
#  [('족보', 1.0), ('남았다', 1.0), ('한참', 1.0)],
#  [('또', 1.0)],
#  [('근데', 1.0), ('가만보니', 1.0)],
#  [('김태환이', 1.0), ('문제네', 1.0)],
#  [('근원인데', 1.0), ('악의', 1.0)],
#  [('이샛기', 1.0)],
#  [('선동질', 1.0)],
#  [('모함', 1.0)],
#  [('비하', 1.0)],
#  [('선동이라니', 1.0)],
#  [('난', 1.0), ('그런거', 1.0), ('안해', 1.0)],
#  [('어마어마한데', 1.0)],
#  [('앞잡이느낌든거', 1.0)],
#  [('나뿐이냐', 1.0)],
#  [('배웠겠어', 1.0), ('앞잡이', 1.0), ('어디서', 1.0)],
#  [('락원이', 1.0), ('잡아서', 1.0), ('허점', 1.0)],
#  [('얘기하고', 1.0), ('우리한테', 1.0)],
#  [('동현', 1.0), ('배운거지', 1.0), ('선배한테', 1.0)],
#  [('같이', 1.0), ('욕하자', 1.0)],
#  [('봐봐', 1.0)],
#  [('또', 1.0)],
#  [('시작이네', 1.0)],
#  [('많은데', 1.0), ('문제가', 1.0), ('선배들이', 1.0)],
#  [('이샛깈', 1.0)],
#  [('어떡하겠노', 1.0)],
#  [('떠넘기기까지', 1.0), ('이렇게', 1.0)],
#  [('태환', 1.0)],
#  [('국회의원해라', 1.0)],
#  [('니', 1.0), ('직업', 1.0), ('찾았다', 1.0)],
#  [('니', 1.0), ('가면', 1.0), ('거기', 1.0)],
#  [('성공한다', 1.0)],
#  [('진짜', 1.0), ('맨날', 1.0), ('자기는', 1.0), ('잘못없고', 1.0)],
#  [('때문이라함', 1.0), ('사람', 1.0), ('옆에', 1.0)],
#  [('아니', 1.0), ('난', 1.0), ('기만질', 1.0), ('안하잖아', 1.0)],
#  [('그리고', 1.0), ('웃긴건뭔지암', 1.0)],
#  [('놀리기만', 1.0), ('살짝', 1.0), ('처음에', 1.0), ('하고', 1.0)],
#  [('옆사람한테', 1.0)],
#  [('바통넘겨즈고', 1.0)],
#  [('뒤에서', 1.0), ('웃고만', 1.0), ('있음', 1.0), ('지는', 1.0)],
#  [('그리고', 1.0), ('뭐라하면', 1.0), ('피해자가', 1.0)],
#  [('시발', 1.0), ('정곡을', 1.0), ('찔리네', 1.0)],
#  [('난', 1.0), ('아무것도', 1.0), ('안했어', 1.0)],
#  [('난', 1.0), ('웃기만했어', 1.0)],
#  [('시전', 1.0)],
#  [('간신', 1.0), ('샵검색', 1.0)],
#  [('떠넘기기', 1.0), ('바로', 1.0), ('옆사람', 1.0)],
#  [('태환이형', 1.0)],
#  [('근데', 1.0), ('그', 1.0), ('누군지암', 1.0), ('옆사람이', 1.0)],
#  [('여기', 1.0), ('출연했다매', 1.0)],
#  [('허정훈', 1.0)],
#  [('왜', 1.0), ('새로', 1.0), ('옷을', 1.0), ('입었냐가', 1.0), ('중요하지', 1.0)],
#  [('태환', 1.0), ('정훈', 1.0), ('조합', 1.0)],
#  [('아찔한데이겈', 1.0)],
#  [('왜', 1.0), ('갑자기', 1.0), ('공격', 1.0), ('나는', 1.0), ('받은거냐', 1.0)],
#  [('아', 1.0), ('놀린게', 1.0), ('동현이까지', 1.0), ('실수였나보네', 1.0), ('이번에', 1.0)],
#  [('난', 1.0),
#   ('다르긴', 1.0),
#   ('밖에서', 1.0),
#   ('옷이랑', 2.0),
#   ('입는', 2.0),
#   ('집에서', 1.0),
#   ('함', 1.0)],
#  [('다음번엔', 1.0), ('잘나눠야겠노', 1.0), ('팀', 1.0)],
#  [('락원이는', 1.0)],
#  [('늘', 1.0), ('운동복만', 1.0), ('입고', 1.0), ('있어', 1.0)],
#  [('넌', 1.0), ('모르네', 1.0), ('아직도', 1.0), ('잘', 1.0), ('친구를', 1.0)],
#  [('실망이다', 1.0)],
#  [('홀리', 1.0), ('쉿', 1.0)],
#  [('락원이는', 1.0), ('받아야해', 1.0), ('실망감', 1.0), ('좀', 1.0)],
#  [('아', 1.0), ('니가', 1.0), ('허정훈', 1.0), ('실망한거였냐', 1.0)],
#  [('글지', 1.0)],
#  [('홀리몰리', 1.0)],
#  [('뎀쓌', 1.0)],
#  [('오늘은', 1.0), ('쨋든', 1.0)],
#  [('태환아', 1.0), ('하', 1.0)],
#  [('시험기간', 1.0), ('재밌었다', 1.0)],
#  [('공방전이', 1.0), ('동현이의', 1.0), ('락원이와', 1.0), ('치열한', 1.0)],
#  [('니덕에', 1.0)],
#  [('멋있었다', 1.0)],
#  [('누가', 1.0), ('궁금함', 1.0), ('이길지', 1.0), ('조금', 1.0)],
#  [('동현이', 1.0), ('진짜', 1.0), ('느꼈는데', 1.0), ('생파때', 1.0), ('저번에', 1.0)],
#  [('락원이', 1.0), ('조만간', 1.0)],
#  [('동현이', 1.0),
#   ('근데', 1.0),
#   ('아', 1.0),
#   ('10프로였음로', 1.0),
#   ('락원이한테', 1.0),
#   ('선동한건', 1.0)],
#  [('신고함', 1.0), ('학교폭력으로', 1.0)],
#  [('좀', 1.0), ('오늘은', 1.0), ('적었다', 1.0)],
#  [('근데', 1.0), ('락원이', 1.0), ('이렇게', 1.0), ('서포팅', 1.0), ('해주는데', 1.0)],
#  [('락원이는', 1.0), ('않네', 1.0), ('읽지도', 1.0), ('카톡을', 1.0)],
#  [('다담즈에', 1.0), ('풀빌라가는데', 1.0)],
#  [('1박', 1.0), ('2인', 1.0), ('43만원나옴', 1.0)],
#  [('비싸긴하더라', 1.0)],
#  [('존나', 1.0), ('비싸네', 1.0)],
#  [('이렇게', 1.0), ('목금', 1.0), ('잡았는데도', 1.0)],
#  [('43만원임', 1.0)],
#  [('락원이', 1.0),
#   ('그러면', 1.0),
#   ('금요일에', 1.0),
#   ('보겠네', 1.0),
#   ('오', 1.0),
#   ('잘하면', 1.0)],
#  [('송정인데', 1.0)],
#  [('락원이', 1.0), ('서핑함', 1.0), ('송정에서', 1.0)],
#  [('락데이트날임', 1.0)],
#  [('샵검색', 1.0), ('마린케이풀빌라', 1.0), ('부산', 1.0)],
#  [('여기임', 1.0)],
#  [('이쁘지않냐', 1.0)],
#  [('5주년기념', 1.0), ('데이트하러감', 1.0)],
#  [('5365', 1.0), ('머리로', 1.0), ('참았다', 1.0), ('해보려다가', 1.0)],
#  [('김태환', 1.0), ('선영이한테', 1.0)],
#  [('1825', 1.0)],
#  [('천몇백일', 1.0), ('축하한다했은데', 1.0)],
#  [('2로', 1.0), ('된다이가', 1.0), ('하면', 1.0)],
#  [('1800일', 1.0), ('이미', 1.0), ('지났다고', 1.0), ('하니깐', 1.0)],
#  [('일하는데', 1.0), ('친구', 1.0), ('포항', 1.0), ('풀빌라애서', 1.0)],
#  [('수', 1.0), ('있는데', 1.0), ('할인해달라고', 1.0), ('해줄', 1.0)],
#  [('태환', 1.0), ('1900일', 1.0), ('곧', 1.0), ('오잖아', 1.0)],
#  [('동현', 1.0), ('오', 1.0)],
#  [('혹시', 1.0), ('있음', 1.0), ('개인', 1.0), ('거기도', 1.0), ('수영장', 1.0)],
#  [('사이트', 1.0), ('알려줄스있음', 1.0), ('주소', 1.0)],
#  [('마치블루', 1.0)],
#  [('여기', 1.0), ('좀', 1.0), ('많이', 1.0), ('온다', 1.0), ('유명인들', 1.0)],
#  [('미안', 1.0), ('동현', 1.0)],
#  [('내가', 1.0), ('돈이업다', 1.0)],
#  [('73만원', 1.0)],
#  [('좋은방아니가', 1.0)],
#  [('기본방임', 1.0)],
#  [('개인', 1.0), ('수영장있는거', 1.0)],
#  [('더', 1.0), ('니가', 1.0), ('넓긴하네', 1.0), ('방자체가', 1.0), ('보내준거는', 1.0)],
#  [('하고', 1.0), ('이쁘기도', 1.0)],
#  [('근데', 1.0), ('그럼', 1.0), ('좀', 1.0), ('교통이', 1.0), ('너무비싸고', 1.0)],
#  [('아깝누', 1.0)],
#  [('공부하고', 1.0), ('왔더니', 1.0), ('카톡', 1.0), ('핫하네', 1.0)],
#  [('니', 1.0), ('내가', 1.0), ('락원', 1.0), ('오랜만에', 1.0), ('편들어줬다', 1.0)],
#  [('내편이', 1.0), ('정상인거지', 1.0)],
#  [('아', 1.0), ('이걸', 1.0), ('찌르네', 1.0)],
#  [('선영이도', 1.0)],
#  [('꼽주는거', 1.0)],
#  [('어디가서', 1.0)],
#  [('안밀린다니까', 1.0)],
#  [('매력포인트지', 1.0)],
#  [('아', 1.0), ('잘못뒀다', 1.0), ('집부', 1.0)],
#  [('락원아', 1.0), ('난', 1.0), ('항상', 1.0), ('네', 1.0), ('편이야', 1.0)],
#  [('친구', 1.0), ('사이에', 1.0), ('어딨냐;;', 1.0), ('편이', 1.0)],
#  [('93점', 1.0), ('드리겠습니다', 1.0), ('명언', 1.0), ('점수', 1.0)],
#  [('락원이를', 1.0),
#   ('말하는거지', 1.0),
#   ('생각', 1.0),
#   ('안하니깐', 1.0),
#   ('저렇게', 1.0),
#   ('친구로', 1.0),
#   ('태환이는', 1.0)],
#  [('점수', 1.0), ('이거에', 1.0), ('줘야지', 1.0)],
#  [('드리겠습니다', 1.0), ('88점', 1.0)],
#  [('족보', 1.0),
#   ('벡해', 1.0),
#   ('있나', 1.0),
#   ('작년에', 1.0),
#   ('표햄', 1.0),
#   ('푼거', 1.0)],
#  [('가노', 1.0), ('왤케', 1.0), ('일찍', 1.0)],
#  [('6시반에', 1.0), ('왔다', 1.0)],
#  [('피곤쓰', 1.0)],
#  [('엥', 1.0)],
#  [('지금', 1.0), ('나', 1.0)],
#  [('도착했는데', 1.0)],
#  [('어떻게', 1.0), ('그럼', 1.0), ('되는거임', 1.0)],
#  [('동현이', 1.0), ('락원이', 1.0), ('시험', 1.0), ('잘쳐', 1.0)],
#  [('말안해도', 1.0), ('잘치겠지만', 1.0)],
#  [('락원', 1.0), ('공부안해도', 1.0), ('나오더라', 1.0), ('에이제로는', 1.0)],
#  [('아까', 1.0), ('나한테', 1.0), ('라고', 1.0), ('말함', 1.0)],
#  [('이건', 1.0), ('팩트임', 1.0)],
#  [('하는데', 1.0), ('이렇게', 1.0), ('말하니깐', 1.0), ('보이긴', 1.0), ('선동처럼', 1.0)],
#  [('진짜', 1.0), ('맞음', 1.0), ('실상은', 1.0), ('팩트', 1.0)],
#  [('안나오던데', 1.0)],
#  [('진짜', 1.0), ('이현직이네', 1.0)],
#  [('사칭아니긴함', 1.0)],
#  [('너무', 1.0), ('도서관', 1.0), ('추운데', 1.0)],
#  [('온도', 1.0), ('올려야하나', 1.0)],
#  [('태환', 1.0), ('카톡', 1.0), ('공소지하오면', 1.0)],
#  [('끝나면', 1.0), ('나올게', 1.0), ('데리고', 1.0), ('락새끼', 1.0)],
#  [('어디서', 1.0), ('먹을래', 1.0)],
#  [('추운데', 1.0), ('날도', 1.0)],
#  [('뚜뚜주', 1.0), ('뜨끈한', 1.0)],
#  [('이근', 1.0)],
#  [('두근두근', 1.0)],
#  [('메뉴', 1.0), ('문제있숴', 1.0)],
#  [('태환', 1.0), ('어디임', 1.0)],
#  [('태디', 1.0)],
#  [('나', 1.0), ('공소도착3분전', 1.0)],
#  [('이건찐', 1.0)],
#  [('지하에서보자', 1.0), ('표', 1.0)],
#  [('옥상이나챠와', 1.0)],
#  [('옥상임', 1.0)],
#  [('꺼져', 1.0)],
#  [('이현직', 1.0)],
#  [('길다', 1.0), ('팔', 1.0)],
#  [('닿이겠는데', 1.0), ('무릎', 1.0), ('손가락피면', 1.0)],
#  [('이네', 1.0)],
#  [('직섹시', 1.0)],
#  [('락원', 1.0), ('도서관', 1.0), ('끝나면', 1.0), ('앞', 1.0)],
#  [('왜', 1.0), ('태환', 1.0), ('나는', 1.0), ('안불러주냐', 1.0)],
#  [('삼각김밥아', 1.0)],
#  [('웃기네', 1.0), ('존나', 1.0), ('머리', 1.0), ('현직이', 1.0)],
#  [('니', 1.0), ('배신', 1.0), ('좆되더라', 1.0)],
#  [('먹으려고', 1.0), ('삼각김밥', 1.0), ('저녁에', 1.0)],
#  [('사둔건데', 1.0)],
#  [('점심', 1.0), ('니랑', 1.0), ('먹을려고', 1.0), ('했는데', 1.0)],
#  [('그럼', 1.0),
#   ('꺼져', 1.0),
#   ('나와', 1.0),
#   ('라고하면', 1.0),
#   ('응', 1.0),
#   ('이럴거잖아', 1.0)],
#  [('서운하다진짜', 1.0)],
#  [('씨발련아', 1.0), ('에이', 1.0)],
#  [('친구를', 1.0), ('개샛기로', 1.0), ('니는', 1.0), ('보노', 1.0)],
#  [('진짜', 1.0), ('태환', 1.0)],
#  [('두말하겠나', 1.0), ('표선이가', 1.0), ('한입으로', 1.0)],
#  [('나와', 1.0), ('그런', 1.0)],
#  [('어떻게', 1.0), ('그렇게', 1.0), ('친구를', 1.0), ('닌', 1.0), ('보냐', 1.0)],
#  [('그럼', 1.0)],
#  [('사과해라', 1.0)],
#  [('사과', 1.0)],
#  [('다', 1.0), ('이정도면', 1.0), ('할거', 1.0), ('했지', 1.0)],
#  [('같이나와', 1.0), ('락데리고', 1.0)],
#  [('나', 1.0), ('시험칠거임', 1.0), ('점심안먹고', 1.0)],
#  [('련아', 1.0)],
#  [('죽어', 1.0)],
#  [('오늘', 1.0), ('일단', 1.0), ('표선이', 1.0)],
#  [('락원이보다', 1.0), ('심했다', 1.0)],
#  [('락밑표', 1.0)],
#  [('나', 1.0), ('먼저', 1.0), ('버림', 1.0), ('태환이가', 1.0)],
#  [('곧', 1.0), ('가겠네', 1.0), ('밑으로도', 1.0), ('있으면', 1.0), ('직이', 1.0)],
#  [('공부하러', 1.0), ('나랑같이', 1.0), ('온다해넣고', 1.0)],
#  [('바로', 1.0), ('도서관으로', 1.0)],
#  [('튐', 1.0)],
#  [('그런적', 1.0), ('없음', 1.0)],
#  [('나랑', 1.0), ('만나고', 1.0)],
#  [('2분뒤에', 1.0)],
#  [('이거', 1.0), ('다', 1.0), ('거짓말인거', 1.0), ('아시죠', 1.0), ('여러분', 1.0)],
#  [('놑열', 1.0), ('어', 1.0), ('열렸다', 1.0)],
#  [('빠이', 1.0)],
#  [('하고', 1.0), ('가버림', 1.0)],
#  [('이건', 1.0), ('진짜;', 1.0)],
#  [('쌍방', 1.0), ('이번건', 1.0)],
#  [('이걸', 1.0), ('사온거지', 1.0), ('삼김을', 1.0), ('예상하고', 1.0)],
#  [('일방임', 1.0)],
#  [('근데', 1.0), ('먼저', 1.0), ('너가', 1.0), ('벌레짓해서', 1.0), ('한거지', 1.0)],
#  [('삼김을', 1.0), ('사', 1.0)],
#  [('이걸', 1.0), ('예상하고', 1.0), ('산거지', 1.0)],
#  [('난', 1.0), ('너가', 1.0), ('그래서', 1.0), ('그런거지', 1.0)],
#  [('뛰어나다고', 1.0), ('봐야하는거지', 1.0), ('준비성이', 1.0)],
#  [('웃기네', 1.0)],
#  [('더', 1.0),
#   ('근데', 1.0),
#   ('아니', 1.0),
#   ('있음', 1.0),
#   ('얘기가', 1.0),
#   ('중요한', 1.0)],
#  [('대박이네', 1.0)],
#  [('동현이', 1.0), ('락원이', 1.0), ('공부안했다몀서', 1.0)],
#  [('개쩐다', 1.0)],
#  [('오래', 1.0), ('왜케', 1.0), ('있노', 1.0)],
#  [('연막', 1.0), ('이틀이가', 1.0), ('하루', 1.0)],
#  [('그니간', 1.0)],
#  [('없제', 1.0), ('아직도', 1.0), ('속는', 1.0), ('흑우', 1.0)],
#  [('아', 1.0), ('그래도', 1.0), ('믿어봤는데', 1.0)],
#  [('또', 1.0), ('이걸', 1.0), ('속았네', 1.0), ('에쿠', 1.0)],
#  [('껄껄', 1.0)],
#  [('진짜', 1.0), ('니는', 1.0), ('안되겠다', 1.0)],
#  [('내가', 1.0),
#   ('13년', 1.0),
#   ('니한테', 1.0),
#   ('뒤', 1.0),
#   ('사기침', 1.0),
#   ('정확히', 1.0)],
#  [('당해주셈', 1.0)],
#  [('사기는', 1.0), ('아니고', 1.0), ('아니지', 1.0)],
#  [('보증', 1.0), ('부탁함', 1.0), ('서달라고', 1.0)],
#  [('13년뒤까지', 1.0), ('연락하면', 1.0)],
#  [('보증정도는', 1.0), ('서주지', 1.0)],
#  [('태환', 1.0), ('돈', 1.0), ('빌려줘', 1.0)],
#  [('13년', 1.0), ('채우고와', 1.0)],
#  [('아니', 1.0), ('쒸팔', 1.0)],
#  [('몇시간이야', 1.0), ('시험이', 1.0)],
#  [('형', 1.0), ('힘들다', 1.0)],
#  [('연막충', 1.0)],
#  [('김락원이랑', 1.0), ('끝까지', 1.0), ('남아있는거아님', 1.0), ('동현이만', 1.0)],
#  [('류지까지', 1.0)],
#  [('남았때', 1.0), ('셋', 1.0)],
#  [('개빡치네', 1.0)],
#  [('류지', 1.0)],
#  [('나', 1.0), ('아직', 1.0), ('좋아함', 1.0)],
#  [('락원이', 1.0), ('좋아함', 1.0)],
#  [('락원이한테서', 1.0), ('모습이', 1.0), ('보였음', 1.0), ('오늘보니깐', 1.0), ('태성이', 1.0)],
#  [('살짝', 1.0)],
#  [('아기', 1.0), ('태성임', 1.0)],
#  [('아니고', 1.0), ('아직', 1.0), ('성인까지는', 1.0)],
#  [('보니깐', 1.0), ('근데', 1.0), ('오늘', 1.0)],
#  [('좀', 1.0), ('어마무시하던데', 1.0)],
#  [('뒤져따', 1.0), ('이따', 1.0), ('카페에서', 1.0)],
#  [('아', 1.0), ('왤케', 1.0), ('설사를', 1.0), ('하지', 1.0)],
#  [('락원', 1.0)],
#  [('다음학기', 1.0), ('확통', 1.0)],
#  [('이미경교수님이래', 1.0)],
#  [('괜찮을듯', 1.0)],
#  [('락투', 1.0)],
#  [('개씹쌉꿀이고', 1.0)],
#  [('방금김상일교수님만났는데', 1.0)],
#  [('2학기', 1.0), ('확통하냐고물어보니깐', 1.0)],
#  [('이미경교수님이하신다함', 1.0), ('확통은', 1.0)],
#  [('김상일교수님', 1.0), ('해석2하신데', 1.0)],
#  [('개꿀이네', 1.0), ('김상일이면', 1.0), ('해석', 1.0)],
#  [('아니', 1.0), ('꿀이지', 1.0), ('솔직히', 1.0), ('신기연만', 1.0), ('안오면', 1.0)],
#  [('개꿀인데', 1.0), ('미루길', 1.0), ('잘했네', 1.0)],
#  [('락원이', 1.0)],
#  [('시험은', 1.0), ('어땠음', 1.0), ('이번', 1.0)],
#  [('조졌나', 1.0)],
#  [('연막', 1.0),
#   ('굳이', 1.0),
#   ('비도', 1.0),
#   ('와서', 1.0),
#   ('치지말자', 1.0),
#   ('흐린데', 1.0)],
#  [('그냥', 1.0), ('그럭저럭', 1.0), ('친듯', 1.0)],
#  [('다', 1.0), ('풀었네', 1.0)],
#  [('고생했다', 1.0)],
#  [('카페가나', 1.0)],
#  [('왜', 1.0),
#   ('되냐', 1.0),
#   ('다', 1.0),
#   ('그럭저럭', 1.0),
#   ('친게', 1.0),
#   ('푼게', 1.0)],
#  [('그냥', 1.0), ('각자', 1.0), ('비오는데', 1.0), ('하자', 1.0)],
#  [('넌', 1.0), ('부정적이야', 1.0), ('애가', 1.0)],
#  [('각자', 1.0)],
#  [('상처', 1.0)],
#  [('처상', 1.0)],
#  [('상처받아도', 1.0), ('알겠다고', 1.0), ('친구가', 1.0)],
#  [('오늘', 1.0),
#   ('락원이', 1.0),
#   ('5번째', 1.0),
#   ('만들기로', 1.0),
#   ('썸', 1.0),
#   ('어떻게되는건데', 1.0),
#   ('우리', 1.0),
#   ('한건', 1.0)],
#  [('반할만하너', 1.0)],
#  [('친구가', 1.0), ('공감해주라고', 1.0), ('상처받으면', 1.0), ('하잖아', 1.0)],
#  [('이건', 1.0)],
#  [('왜', 1.0), ('공감', 1.0), ('무시해', 1.0), ('안하고', 1.0)],
#  [('종강', 1.0)],
#  [('수학과', 1.0), ('이제', 1.0), ('졸업이다', 1.0)],
#  [('고생했노', 1.0)],
#  [('돼지', 1.0)],
#  [('고맙다', 1.0)],
#  [('멸치', 1.0)],
#  [('오늘', 1.0), ('나가지마라', 1.0), ('현직아', 1.0)],
#  [('날아간다', 1.0), ('바람에', 1.0)],
#  [('정훈아', 1.0)],
#  [('드디어', 1.0), ('락원이가', 1.0), ('연락이', 1.0), ('왔음', 1.0), ('저녁먹자고', 1.0)],
#  [('에이', 1.0)],
#  [('농담하지마셈', 1.0)],
#  [('꿈꾸는거', 1.0), ('아님', 1.0)],
#  [('아아니야', 1.0)],
#  [('락원이가', 1.0), ('그랬단', 1.0), ('말이야', 1.0)],
#  [('오늘', 1.0), ('오랜만에', 1.0), ('치킨', 1.0)],
#  [('안먹', 1.0)],
#  [('아', 1.0)],
#  [('닭', 1.0), ('땡기면', 1.0), ('먹고오셈', 1.0)],
#  [('저녁', 1.0), ('나', 1.0), ('됨', 1.0), ('안먹어도', 1.0)],
#  [('하마', 1.0)],
#  [('매좋', 1.0)],
#  [('몇시', 1.0)],
#  [('6시', 1.0)],
#  [('존나', 1.0), ('매좆', 1.0), ('패고싶네', 1.0)],
#  [('비', 1.0), ('옴', 1.0)],
#  [('개빨리뜨네', 1.0), ('성적', 1.0), ('편미방', 1.0)],
#  [('동현아', 1.0), ('점수', 1.0), ('까자', 1.0)],
#  [('난', 1.0), ('97', 1.0)],
#  [('난', 1.0), ('138', 1.0)],
#  [('현직이', 1.0), ('살빠졌네', 1.0)],
#  [('97키로이고싶다', 1.0)],
#  [('성적', 1.0), ('편미방', 1.0), ('버로나오메', 1.0)],
#  [('0이', 1.0), ('100는', 1.0), ('몇개', 1.0), ('있을까', 1.0)],
#  [('0이', 1.0), ('100', 1.0), ('두개있네', 1.0), ('여기엔', 1.0)],
#  [('6×424', 1.0)],
#  [('예', 1.0)],
#  [('5의', 1.0), ('갯수만큼', 1.0), ('소인수분해', 1.0), ('있을테니깐', 1.0), ('했을때', 1.0)],
#  [('캬', 1.0)],
#  [('저', 1.0), ('대강', 1.0), ('부근일걸', 1.0)],
#  [('니도', 1.0), ('역시', 1.0)],
#  [('괴물은', 1.0), ('괴물이다', 1.0)],
#  [('24개임', 1.0), ('실제로', 1.0)],
#  [('락앞에서', 1.0), ('부끄럽다', 1.0)],
#  [('조용히', 1.0), ('해', 1.0)],
#  [('답', 1.0),
#   ('락원이는', 1.0),
#   ('이미', 1.0),
#   ('말', 1.0),
#   ('아는데', 1.0),
#   ('안하는중', 1.0)],
#  [('니', 1.0), ('몇초만에', 1.0), ('볼라고', 1.0), ('푸는지', 1.0)],
#  [('락원', 1.0)],
#  [('왜', 1.0), ('내', 1.0), ('답은', 1.0)],
#  [('정훈아', 1.0), ('무시하냐', 1.0)],
#  [('하고', 1.0), ('락원', 1.0), ('앞으로', 1.0), ('해야한디', 1.0)],
#  [('대박이네', 1.0)],
#  [('고맙다', 1.0)],
#  [('이게', 1.0), ('재능이지', 1.0)],
#  [('오늘', 1.0),
#   ('락원이', 1.0),
#   ('다', 1.0),
#   ('말', 1.0),
#   ('무시하네', 1.0),
#   ('한', 1.0)],
#  [('11시까지', 1.0), ('복기문', 1.0), ('제출해', 1.0)],
#  [('어떻게', 1.0),
#   ('락원이', 1.0),
#   ('공평하게', 1.0),
#   ('내기를', 1.0),
#   ('동전이', 1.0),
#   ('때', 1.0),
#   ('맞추는', 1.0),
#   ('앞뒤를', 1.0),
#   ('찌그러져있을', 1.0),
#   ('하려면', 1.0),
#   ('해야해', 1.0)],
#  [('락원이', 1.0), ('꼭', 1.0), ('숙제', 1.0), ('해라', 1.0)],
#  [('오늘', 1.0), ('11시야', 1.0)],
#  [('5분이면', 1.0), ('안다', 1.0), ('이거는', 1.0), ('읽은거', 1.0), ('충분하제', 1.0)],
#  [('동전', 1.0),
#   ('성의없는', 1.0),
#   ('소리', 1.0),
#   ('이딴', 1.0),
#   ('펴야지', 1.0),
#   ('하지말자', 1.0)],
#  [('배드민턴', 1.0),
#   ('진짜', 1.0),
#   ('집에', 1.0),
#   ('그러면', 1.0),
#   ('내기할꺼임', 1.0),
#   ('너네', 1.0),
#   ('있는', 1.0),
#   ('찌그러트려서', 1.0),
#   ('채', 1.0)],
#  [('다시', 1.0), ('펴줄게', 1.0)],
#  [('락원이', 1.0), ('뭐라', 1.0), ('설렌다', 1.0), ('얘기할지', 1.0)],
#  [('어떻게', 1.0), ('다르지', 1.0), ('따라', 1.0), ('않나', 1.0), ('찌그러져있는지에', 1.0)],
#  [('음', 1.0), ('어떻게', 1.0), ('찌그러져있더라도', 1.0)],
#  [('내기를', 1.0), ('동일하게', 1.0), ('하고자한다면', 1.0)],
#  [('아', 1.0), ('개가기싫네', 1.0), ('새도', 1.0)],
#  [('찌그러져있을', 1.0), ('p를', 1.0), ('때의', 1.0), ('모름', 1.0), ('확률', 1.0)],
#  [('올걸', 1.0), ('짐들고', 1.0)],
#  [('동현아', 1.0)],
#  [('기만질이냐', 1.0)],
#  [('시험다끝났는데', 1.0)],
#  [('짐가지러가기귀찮다고하는건', 1.0)],
#  [('다시', 1.0), ('새도', 1.0), ('갈라고', 1.0)],
#  [('왔는데', 1.0), ('짐두고', 1.0)],
#  [('비가', 1.0), ('안그치네', 1.0)],
#  [('이거는', 1.0), ('같은데', 1.0), ('아닌거', 1.0), ('통계문제가', 1.0)],
#  [('빨리와', 1.0)],
#  [('거의', 1.0), ('살면서', 1.0), ('없어', 1.0), ('통계문제는', 1.0)],
#  [('니가', 1.0),
#   ('살짝', 1.0),
#   ('가장', 1.0),
#   ('잘하는', 1.0),
#   ('창의수리지', 1.0),
#   ('통계문제라기보다', 1.0)],
#  [('이게', 1.0), ('진짜', 1.0), ('기만이지', 1.0)],
#  [('진짜', 1.0), ('역겹다', 1.0)],
#  [('기말15등아면', 1.0), ('에이쁠안되는거아니냨', 1.0)],
#  [('저', 1.0),
#   ('잘', 1.0),
#   ('친구가', 1.0),
#   ('글입니다', 1.0),
#   ('내려주세요', 1.0),
#   ('모르고', 1.0),
#   ('올린', 1.0),
#   ('제', 1.0)],
#  [('락원', 1.0)],
#  [('30프로까지', 1.0), ('되긋니', 1.0), ('에이인데', 1.0)],
#  [('되긋지', 1.0)],
#  [('태환이형', 1.0), ('담타', 1.0)],
#  [('방금하고', 1.0), ('왔는뎅', 1.0)],
#  [('30분에', 1.0)],
#  [('아', 1.0), ('그럼', 1.0), ('새도', 1.0), ('30분에', 1.0), ('갈게', 1.0)],
#  [('동현', 1.0), ('9시까디', 1.0), ('갔다가', 1.0), ('부산대역', 1.0)],
#  [('담타', 1.0)],
#  [('갈게', 1.0), ('비안오면', 1.0)],
#  [('지금', 1.0), ('동현', 1.0), ('출발해', 1.0)],
#  [('2분', 1.0), ('나갈게', 1.0), ('뒤에', 1.0)],
#  [('지금', 1.0), ('출발할게', 1.0)],
#  [('지금', 1.0), ('우리', 1.0), ('나옴', 1.0)],
#  [('나갔노', 1.0), ('내버리고', 1.0)],
#  [('나와', 1.0), ('기다리는중임', 1.0)],
#  [('락원이', 1.0), ('언제', 1.0), ('풀어주노', 1.0)],
#  [('내', 1.0), ('떨리면서', 1.0), ('부랄', 1.0)],
#  [('기다리는', 1.0), ('중인데', 1.0)],
#  [('난', 1.0), ('모르겠는데', 1.0), ('저거', 1.0)],
#  [('물어봐', 1.0), ('태환이한테', 1.0)],
#  [('내가', 1.0), ('너가', 1.0), ('모르는걸', 1.0), ('알리가', 1.0)],
#  [('톡방의', 1.0), ('희망', 1.0)],
#  [('김락1', 1.0)],
#  [('락원', 1.0), ('대답을', 1.0), ('창의적인', 1.0), ('해줘', 1.0)],
#  [('1', 1.0)],
#  [('1', 1.0)],
#  [('일단', 1.0),
#   ('lemma로', 1.0),
#   ('가하면', 1.0),
#   ('무게중심이', 1.0),
#   ('물리적인', 1.0),
#   ('변했으니깐', 1.0),
#   ('안되는거까지', 1.0),
#   ('임의로', 1.0),
#   ('줄게', 1.0),
#   ('찌그러', 1.0),
#   ('트렸으면', 1.0),
#   ('힘을', 1.0)],
#  [('다', 1.0), ('11시까지', 1.0), ('둘', 1.0), ('제출해줘', 1.0)],
#  [('내일', 1.0), ('난', 1.0), ('시험임', 1.0)],
#  [('아니', 1.0)],
#  [('문제', 1.0), ('보고서랑', 1.0)],
#  [('아', 1.0), ('락원이', 1.0), ('두개', 1.0), ('제출이네', 1.0)],
#  [('락1이', 1.0), ('못해;;', 1.0), ('밖에', 1.0), ('저건', 1.0)],
#  [('형', 1.0), ('1', 1.0), ('2', 1.0), ('락', 1.0)],
#  [('락12', 1.0)],
#  [('0락2한테', 1.0), ('물어봐도', 1.0), ('봐줌', 1.0)],
#  [('락풍년이고', 1.0), ('수학과에', 1.0)],
#  [('락원이는', 1.0),
#   ('이렇게', 1.0),
#   ('많이', 1.0),
#   ('관심', 1.0),
#   ('받아서', 1.0),
#   ('좋겠다', 1.0)],
#  [('지금', 1.0),
#   ('현직이', 1.0),
#   ('떨리는', 1.0),
#   ('랄부', 1.0),
#   ('부러워서', 1.0),
#   ('중', 1.0)],
#  [('중', 1.0), ('대신', 1.0), ('떠는', 1.0), ('맞게', 1.0), ('비트에', 1.0)],
#  [('락풍년', 1.0)],
#  [('역시', 1.0), ('우리과', 1.0), ('지상락원이지', 1.0)],
#  [('시발', 1.0)],
#  [('와시발', 1.0)],
#  [('싶은데', 1.0), ('이기고', 1.0)],
#  [('찢었다', 1.0)],
#  [('한다', 1.0)],
#  [],
#  [('1', 1.0)],
#  [('나도', 1.0), ('내일', 1.0), ('시험이야', 1.0)],
#  [('농담도', 1.0)],
#  [('니한테', 1.0), ('뭐랄까', 1.0), ('저거는', 1.0)],
#  [('머리', 1.0), ('식히기', 1.0)],
#  [('정도다이가', 1.0)],
#  [('배드민턴칠때', 1.0)],
#  [('머리많이쓰니까', 1.0)],
#  [('식히는군', 1.0), ('저런식으로', 1.0)],
#  [('1', 1.0)],
#  [('1', 1.0)],
#  [('가노', 1.0), ('언제', 1.0)],
#  [('한340분뒤', 1.0)],
#  [('빨끝내라', 1.0)],
#  [('일단', 1.0), ('똥부터', 1.0), ('싸고', 1.0), ('얍', 1.0)],
#  [('몇시에', 1.0), ('내일', 1.0), ('옴', 1.0)],
#  [('대강', 1.0), ('78사이', 1.0)],
#  [('나', 1.0), ('교육받는', 1.0), ('프로그램에서', 1.0)],
#  [('다시', 1.0), ('기초', 1.0), ('파이썬', 1.0), ('하라고', 1.0)],
#  [('듣는데', 1.0), ('수업', 1.0), ('여기서', 1.0)],
#  [('니도', 1.0), ('들으셈', 1.0)],
#  [('니는', 1.0), ('파이썬', 1.0), ('마스터인가', 1.0)],
#  [('좆밥이지', 1.0)],
#  [('ptj를', 1.0), ('견딘', 1.0), ('남잔데', 1.0)],
#  [('그러던지', 1.0)],
#  [('다음주에', 1.0), ('들어야지', 1.0)],
#  [('있음', 1.0), ('다시', 1.0), ('저거', 1.0), ('갠톡으로', 1.0), ('줄수', 1.0)],
#  [('내가', 1.0), ('아니다', 1.0), ('하면되지', 1.0)],
#  [('그거', 1.0), ('꾹', 1.0), ('눌러서', 1.0)],
#  [('나에게', 1.0), ('누르면', 1.0), ('버튼', 1.0)],
#  [('감', 1.0), ('바로', 1.0), ('내', 1.0), ('카톡으로', 1.0)],
#  [('굉장히', 1.0), ('알아두셈', 1.0), ('유용하니까', 1.0)],
#  [('같이', 1.0),
#   ('니랑', 1.0),
#   ('락원이랑', 1.0),
#   ('모르는거', 1.0),
#   ('물어봐라', 1.0),
#   ('스터디하고', 1.0)],
#  [('락원아', 1.0), ('파이썬', 1.0), ('다음주', 1.0), ('스터디', 1.0), ('하실', 1.0)],
#  [('태환', 1.0)],
#  [('3일이면', 1.0), ('떡을치지', 1.0)],
#  [('내일', 1.0), ('공소', 1.0), ('몇시에올거임', 1.0)],
#  [('안팎', 1.0), ('한2시', 1.0)],
#  [('락3떡;;', 1.0)],
#  [('하고', 1.0),
#   ('21', 1.0),
#   ('22', 1.0),
#   ('23일', 1.0),
#   ('23일에', 1.0),
#   ('마무으리', 1.0),
#   ('병원에서', 1.0)],
#  [('미쳤따', 1.0)],
#  [('니', 1.0), ('내', 1.0), ('기억하제', 1.0), ('알바도', 1.0)],
#  [('까먹었음', 1.0)],
#  [('28일이였나', 1.0)],
#  [],
#  [('먼저', 1.0), ('간다', 1.0), ('형은', 1.0)],
#  [('내일', 1.0), ('보자', 1.0)],
#  [('김태환', 1.0),
#   ('23일', 1.0),
#   ('28일', 1.0),
#   ('6월', 1.0),
#   ('병원', 1.0),
#   ('알바', 1.0)],
#  [('잘가라잉', 1.0)],
#  [('형', 1.0)],
#  [('나도', 1.0), ('먼저갈게', 1.0)],
#  [('못', 1.0), ('버티겠다', 1.0)],
#  [('김태환', 1.0),
#   ('23일', 1.0),
#   ('28일', 1.0),
#   ('6월', 1.0),
#   ('병원', 1.0),
#   ('알바', 1.0),
#   ('공지', 1.0),
#   ('톡게시판', 1.0)],
#  [('아시발', 1.0)],
#  [('님들', 1.0)],
#  [('1분만', 1.0)],
#  [('김태환이', 1.0), ('오늘은', 1.0), ('라스트찍노', 1.0)],
#  [('짐정리', 1.0), ('할게', 1.0)],
#  [('그럴순', 1.0), ('없다', 1.0)],
#  [('1층에서', 1.0), ('기다림', 1.0)],
#  [('동현이', 1.0), ('꼴찌', 1.0)],
#  [('혹시', 1.0), ('락원이', 1.0)],
#  [('답', 1.0), ('보고서랑', 1.0), ('제출', 1.0), ('했나', 1.0)],
#  [('늦네', 1.0), ('쪼금', 1.0)],
#  [('감점', 1.0), ('되는데', 1.0), ('씨게', 1.0)],
#  [('난', 1.0), ('누움', 1.0), ('잘려고', 1.0)],
#  [('그전에', 1.0)],
#  [('락1아', 1.0), ('제출해야지', 1.0)],
#  [('자야돼', 1.0)],
#  [('하', 1.0)],
#  [('내일', 1.0), ('12시까지는', 1.0), ('제출하자', 1.0)],
#  [('난', 1.0), ('너의', 1.0), ('답이', 1.0), ('듣고싶어', 1.0)],
#  [('좀', 1.0), ('아이패드', 1.0), ('추천', 1.0)],
#  [('가격대와', 1.0), ('승능', 1.0), ('즉당한', 2.0)],
#  [('동현아', 1.0), ('니', 1.0), ('먹혀있다', 1.0), ('자리', 1.0)],
#  [('정훈', 1.0)],
#  [('아이패드', 1.0), ('사셈', 1.0), ('에어', 1.0)],
#  [('가성비갑임', 1.0), ('에어가', 1.0)],
#  [('Air', 1.0)],
#  [('뭐임', 1.0), ('장점이', 1.0)],
#  [('가성비', 1.0)],
#  [('개씹가성비임', 1.0)],
#  [('에어가', 1.0), ('갑', 1.0), ('요새', 1.0), ('프로보다는', 1.0)],
#  [('아이패드가', 1.0)],
#  [('에어', 1.0), ('기본', 1.0), ('프로', 1.0)],
#  [('이렇게', 1.0), ('있거든', 1.0)],
#  [('기본', 1.0), ('미니', 1.0)],
#  [('이렇게', 1.0), ('있음', 1.0)],
#  [('근데', 1.0), ('저번에', 1.0), ('에어가', 1.0), ('새로나오면서', 1.0)],
#  [('거의', 1.0),
#   ('가격은', 1.0),
#   ('비슷한', 1.0),
#   ('성능인데', 1.0),
#   ('프로랑', 1.0),
#   ('훨씬삼', 1.0)],
#  [('쌈', 1.0)],
#  [('고', 1.0)],
#  [('그', 1.0), ('에어랑', 1.0), ('펜이랑', 1.0)],
#  [('사면', 1.0), ('온라인에서', 1.0), ('학생할인으로', 1.0)],
#  [('가장', 1.0)],
#  [('가격비교해봐야함', 1.0)],
#  [('갓팡도', 1.0), ('싸거든', 1.0)],
#  [('킹짱팡', 1.0)],
#  [('오호', 1.0)],
#  [('거기서', 1.0), ('하는구만', 1.0), ('할인도', 1.0)],
#  [('갓팡이랑', 1.0)],
#  [('교육스토어랑', 1.0), ('애플', 1.0)],
#  [('엉엉', 1.0)],
#  [('복지스토어', 1.0)],
#  [('이렇게', 1.0), ('3개확인해야함', 1.0)],
#  [('이모티콘', 1.0)],
#  [('내기억으로', 1.0)],
#  [('쌈', 1.0), ('갓팡이', 1.0), ('애플펜슬은', 1.0), ('제일', 1.0)],
#  [('따로', 1.0), ('사야하노', 1.0)],
#  [('펜슬은', 1.0)],
#  [('그냥', 1.0), ('2세대가', 1.0)],
#  [('기본쓰제', 1.0)],
#  [('그래서', 1.0), ('에어', 1.0), ('2세대임', 1.0), ('사라는거', 1.0)],
#  [('2세대얐거든', 1.0), ('원래', 1.0), ('프로만', 1.0)],
#  [('이번에', 1.0), ('2세대로', 1.0), ('나온', 1.0), ('알고있음', 1.0), ('에어4도', 1.0)],
#  [('그리고', 1.0), ('거기에', 1.0), ('지문인식가능', 1.0)],
#  [('와저래', 1.0), ('크노', 1.0)],
#  [('지리네', 1.0)],
#  [('니', 1.0), ('공부용으로', 1.0), ('사는거맞제', 1.0)],
#  [('그', 1.0), ('인강용이아니라', 1.0)],
#  [('아', 1.0), ('내가말한공부용은', 1.0), ('필기하는거', 1.0)],
#  [('엄', 1.0)],
#  [('강의도', 1.0), ('들을듯', 1.0)],
#  [('왜', 1.0), ('못듣나', 1.0), ('에어로는', 1.0)],
#  [('이', 1.0)],
#  [('쓸려면', 1.0), ('인강용으로만', 1.0)],
#  [('아이패드', 1.0), ('딴거사라고', 1.0), ('말거', 1.0), ('할랬지', 1.0)],
#  [('어떤거', 1.0)],
#  [('그냥', 1.0), ('갤탭같은거', 1.0)],
#  [('으이', 1.0)],
#  [('함', 1.0), ('비교', 1.0), ('해봐야겠네', 1.0)],
#  [('갤탭은', 1.0), ('되게', 1.0), ('들었는데', 1.0), ('안좋다고', 1.0)],
#  [('또', 1.0), ('아닌가베', 1.0), ('요샌', 1.0)],
#  [('이번에', 1.0), ('나온', 1.0), ('갤탭은', 1.0), ('괜찮다고', 1.0), ('들었어요', 1.0)],
#  [('그래도', 1.0), ('아이패드져', 1.0)],
#  [('하', 1.0)],
#  [('방학', 1.0)],
#  [('하', 1.0)],
#  [('방학이다', 1.0)],
#  [('짱깨', 1.0)],
#  [('with', 1.0)],
#  [('오랜만에', 1.0), ('나쁘지않지', 1.0)],
#  [('난', 1.0), ('약속있어', 1.0)],
#  [('락속', 1.0)],
#  [('에반데', 1.0)],
#  [('NN', 1.0), ('With', 1.0)],
#  [('nn', 1.0)],
#  [('with', 1.0)],
#  [('락녀', 1.0), ('새로운', 1.0)],
#  [('그런거', 1.0), ('없다', 1.0)],
#  [('인증해버리자너', 1.0), ('일편단심', 1.0), ('해바라기', 1.0)],
#  [('가자', 1.0), ('허', 1.0)],
#  [('가김', 1.0)],
#  [('도서관와서', 1.0), ('쳐먹는거뿐이네', 1.0), ('하는게', 1.0)],
#  [('이모티콘', 1.0)],
#  [('현직이', 1.0)],
#  [('니꺼까지', 1.0), ('시키께', 1.0)],
#  [('시키께', 1.0), ('짜장으로', 1.0)],
#  [('형', 1.0), ('잘있어', 1.0), ('태환이', 1.0)],
#  [('담', 1.0)],
#  [('태담태담', 1.0)],
#  [('동현이', 1.0), ('가버렸노', 1.0), ('걍', 1.0)],
#  [('정훈', 1.0)],
#  [('암', 1.0), ('홈', 1.0)],
#  [('오늘', 1.0), ('일정', 1.0), ('있었어서', 1.0)],
#  [('아', 1.0)],
#  [('밖에', 1.0), ('비온디', 1.0)],
#  [('내일', 1.0), ('도서관', 1.0)],
#  [('홀리몰리', 1.0)],
#  [('락원이는', 1.0), ('데이트가고', 1.0), ('우리는', 1.0)],
#  [('도서관가네', 1.0)],
#  [('락원인', 1.0), ('공부안해도', 1.0), ('됨', 1.0)],
#  [('졸업하고', 1.0)],
#  [('난', 1.0), ('운동감', 1.0)],
#  [('취집간대잖아', 1.0)],
#  [('락원이', 1.0), ('운동간다고', 1.0)],
#  [('그럼', 1.0), ('같이', 1.0), ('우리랑', 1.0), ('카페가야지', 1.0)],
#  [('안가지', 1.0), ('카페는', 1.0)],
#  [('우같카', 1.0), ('합격', 1.0)],
#  [('알고', 1.0),
#   ('했음', 1.0),
#   ('있고', 1.0),
#   ('내', 1.0),
#   ('갔는데', 1.0),
#   ('들었다', 1.0),
#   ('마스크', 1.0),
#   ('쓰고', 1.0),
#   ('영락이', 1.0),
#   ('유식이형한테도', 1.0),
#   ('이름', 2.0),
#   ('형이', 1.0)],
#  [('기대해도', 1.0), ('되겠지', 1.0), ('쁠', 1.0)],
#  [('점심', 1.0), ('담주', 1.0), ('직', 1.0)],
#  [('화', 1.0)],
#  [('깨우셈', 1.0)],
#  [('우리집온나', 1.0)],
#  [('밥해줌', 1.0)],
#  [('와', 1.0),
#   ('교수님', 1.0),
#   ('김세라', 1.0),
#   ('되심', 1.0),
#   ('박사님', 1.0),
#   ('수학', 1.0),
#   ('해군사관학교', 1.0)],
#  [('굿', 1.0)],
#  [('어떻게', 1.0),
#   ('진짜', 1.0),
#   ('17점이나오지', 1.0),
#   ('30점만점에', 1.0),
#   ('takehome', 1.0),
#   ('시험인데', 1.0),
#   ('위상', 1.0),
#   ('평균이', 1.0)],
#  [('이걸', 1.0),
#   ('구글링도', 1.0),
#   ('놈들이', 1.0),
#   ('던지는', 1.0),
#   ('있네', 1.0),
#   ('허용인데', 1.0)],
#  [('17점이면', 1.0)],
#  [('잘나온거아니냐', 1.0)],
#  [('강의노트', 1.0),
#   ('구글이랑', 1.0),
#   ('나오는데', 1.0),
#   ('반', 1.0),
#   ('보면', 1.0),
#   ('이상은', 1.0)],
#  [('아', 1.0), ('모기한테', 1.0), ('물림', 1.0), ('엉덩이', 1.0)],
#  [('꺼지라', 1.0), ('썅년', 1.0), ('프레드릭소렌드', 1.0)],
#  [('왜', 1.0), ('취소함', 1.0)],
#  [('들으셈', 1.0), ('걍', 1.0)],
#  [('개같은련이', 1.0)],
#  [('과제내고', 1.0), ('매일', 1.0)],
#  [('강제로', 1.0), ('사게하잖아', 1.0), ('책', 1.0)],
#  [('책은', 1.0)],
#  [('어디서', 1.0), ('굴리고', 1.0), ('중고로', 1.0)],
#  [('그냥', 1.0), ('들으세', 1.0)],
#  [('원래', 1.0), ('그따구임', 1.0), ('대실영은', 1.0)],
#  [('했는데', 1.0), ('중고로', 1.0), ('구할려고', 1.0)],
#  [('이거', 1.0), ('사야한데', 1.0), ('새책', 1.0)],
#  [('있는', 1.0), ('입력해서', 1.0), ('좆지랄해야하는데', 1.0), ('책에', 1.0), ('코드', 1.0)],
#  [('사면', 1.0), ('중고로', 1.0), ('그러더라', 1.0), ('못한다고', 1.0)],
#  [('다', 1.0), ('똑같음', 1.0), ('새끼들', 1.0), ('웬만한', 1.0)],
#  [('수', 1.0),
#   ('때', 1.0),
#   ('제일', 1.0),
#   ('걍', 1.0),
#   ('듣는게', 1.0),
#   ('들을', 1.0),
#   ('속', 1.0),
#   ('있을', 1.0),
#   ('편함', 1.0)],
#  [('가야지', 1.0), ('안고', 1.0)],
#  [('대실영따위가', 1.0), ('일게', 1.0)],
#  [('일개', 1.0)],
#  [('탭스한다건', 1.0)],
#  [('태환이', 1.0), ('어디갔냐', 1.0)],
#  [('이미', 1.0), ('땄음', 1.0), ('영어', 1.0)],
#  [('졸업영어는', 1.0)],
#  [('대실영도', 1.0)],
#  [('되는거', 1.0), ('면제', 1.0)],
#  [('아님', 1.0)],
#  [('태환', 1.0), ('오', 1.0), ('몇점나옴', 1.0), ('탭스', 1.0)],
#  [('아님', 1.0), ('면제', 1.0), ('17부턴', 1.0)],
#  [('아님', 1.0), ('텝스', 1.0), ('토플', 1.0)],
#  [('아', 1.0), ('토플', 1.0)],
#  [('몇점나옴', 1.0)],
#  [('76', 1.0)],
#  [('다시보게', 1.0), ('땜에', 1.0), ('라이팅', 1.0), ('스피킹이랑', 1.0)],
#  [('토익변환라면', 1.0)],
#  [('몇점나오는거임', 1.0)],
#  [('몰라', 1.0)],
#  [('다음학기', 1.0), ('때', 1.0), ('어차피', 1.0), ('올릴거라', 1.0), ('재시험쳐서', 1.0)],
#  [('그때', 1.0), ('내려고', 1.0)],
#  [('있음', 1.0),
#   ('수', 1.0),
#   ('낼', 1.0),
#   ('영역별로', 1.0),
#   ('최고점수', 1.0),
#   ('토플은', 1.0)],
#  [('결석했넴', 1.0), ('계절', 1.0), ('아씨', 1.0)],
#  [('히힛', 1.0)],
#  [('그는', 1.0), ('쳤다', 1.0)],
#  [('딸을', 1.0)],
#  [('좀', 1.0), ('가졌으면', 1.0), ('건전한', 1.0), ('사상을', 1.0), ('좋겠어', 1.0)],
#  [('도', 1.0), ('서관', 1.0)],
#  [('간다', 1.0)],
#  [('저', 1.0), ('오', 1.0), ('락', 1.0)],
#  [('저녁', 1.0), ('오늘', 1.0), ('나', 1.0), ('약속있어', 1.0)],
#  [('락원이', 1.0), ('요새', 1.0)],
#  [('자주있네', 1.0), ('저녁약속', 1.0)],
#  [('바쁜', 1.0), ('사람이지', 1.0)],
#  [('표선이', 1.0), ('술마셔야지', 1.0), ('시험끝났는데', 1.0)],
#  [('나', 1.0), ('부산감', 1.0), ('이번주', 1.0), ('일요일에', 1.0)],
#  [('지금대구임', 1.0)],
#  [('동영상', 1.0)],
#  [('귀여운뽀또보는중', 1.0)],
#  [('그면', 1.0), ('술', 1.0), ('월요일', 1.0)],
#  [('락원이', 1.0),
#   ('너무', 1.0),
#   ('요새', 1.0),
#   ('얼굴보기', 1.0),
#   ('연애하더니', 1.0),
#   ('힘들어짐', 1.0)],
#  [('락원', 1.0)],
#  [('닌', 1.0), ('몇일인지', 1.0), ('모르겠지만', 1.0)],
#  [('나', 1.0), ('일요일에', 1.0), ('5주년임', 1.0)],
#  [('같은데', 1.0), ('봤던거', 1.0), ('어제', 1.0)],
#  [('기억', 1.0), ('안나', 1.0)],
#  [('오래됐네', 1.0), ('졸라', 1.0)],
#  [('나', 1.0), ('7월12', 1.0), ('놀러가거든', 1.0)],
#  [('목금', 1.0)],
#  [('담주', 1.0), ('술마실래', 1.0), ('월화', 1.0), ('중에', 1.0)],
#  [('야', 1.0), ('선영아', 1.0), ('졸업', 1.0), ('축하한다', 1.0)],
#  [('야', 1.0), ('고맙다', 1.0)],
#  [('나', 1.0), ('선영이인데', 1.0)],
#  [('그만해', 1.0), ('너', 1.0), ('일베좀', 1.0)],
#  [('너가', 1.0), ('선영아', 1.0), ('하자며', 1.0)],
#  [('야', 1.0), ('그건', 1.0), ('조용하라고', 1.0), ('했잖아', 1.0)],
#  [('쉽지않네', 1.0)],
#  [('야', 1.0), ('너네', 1.0)],
#  [('담주', 1.0), ('월화', 1.0), ('시간되냐', 1.0)],
#  [('5인이상', 1.0), ('풀리지않음', 1.0)],
#  [('아', 1.0), ('7월1일부터인가', 1.0)],
#  [('오늘부터', 1.0)],
#  [('8인임', 1.0)],
#  [('붓산', 1.0)],
#  [('이제', 1.0), ('5인이상때매', 1.0), ('누구생일인데', 1.0), ('안간다', 1.0)],
#  [('불허', 1.0), ('이런거', 1.0)],
#  [('나', 1.0), ('월욜부터', 1.0), ('토욜까지', 1.0), ('풀약', 1.0)],
#  [('그럼', 1.0), ('오늘', 1.0), ('하고', 1.0), ('현직이', 1.0), ('생일로', 1.0)],
#  [('7시까지', 1.0), ('다들', 1.0), ('락원이네집으로', 1.0), ('집합', 1.0)],
#  [('내가', 1.0), ('7시에는', 1.0), ('집에없다', 1.0)],
#  [('이걸', 1.0), ('뺀다고', 1.0)],
#  [('귀엽게자지않냐', 1.0)],
#  [('안불편한가', 1.0), ('저러면', 1.0)],
#  [('락원이도', 1.0), ('누나', 1.0), ('뭐', 1.0), ('앞에서는', 1.0), ('저러는데', 1.0)],
#  [('이모티콘', 1.0)],
#  [('시비냐', 1.0), ('아침부터', 1.0)],
#  [('저렇게', 1.0), ('자주', 1.0), ('잠', 1.0)],
#  [('락원아', 1.0), ('뜻이지;;', 1.0), ('보고싶다는', 1.0), ('시비라니', 1.0)],
#  [('오점몇', 1.0)],
#  [('11시45분', 1.0)],
#  [('나', 1.0),
#   ('나왔는데', 1.0),
#   ('먹고', 1.0),
#   ('방금', 1.0),
#   ('코코볼', 1.0),
#   ('홀리쒯', 1.0)],
#  [('1230어떤데', 1.0)],
#  [('나', 1.0), ('1시에', 1.0), ('안됨', 1.0), ('운동가야해서', 1.0)],
#  [('락원아', 1.0),
#   ('아니', 1.0),
#   ('또', 1.0),
#   ('시험', 1.0),
#   ('그럴거야', 1.0),
#   ('끝나자마자', 1.0)],
#  [('시험이', 1.0), ('끝났으니', 1.0), ('운동가야지', 1.0)],
#  [('왜', 1.0), ('니', 1.0), ('때는', 1.0), ('시험기간일', 1.0)],
#  [('안간척하냐', 1.0)],
#  [('1210', 1.0), ('운동갈꺼', 1.0)],
#  [('챙겨오셈', 1.0)],
#  [('11시50', 1.0)],
#  [('1200', 1.0)],
#  [('이정도면', 1.0)],
#  [('많이', 1.0), ('양보했다', 1.0)],
#  [('니', 1.0), ('내', 1.0), ('15분', 1.0), ('30분', 1.0)],
#  [('12시', 1.0)],
#  [('왜', 1.0),
#   ('형', 1.0),
#   ('김태환', 1.0),
#   ('17', 1.0),
#   ('건방지게', 1.0),
#   ('대답이', 1.0),
#   ('없노', 1.0)],
#  [('아', 1.0), ('이샛기', 1.0), ('기절했나', 1.0)],
#  [('북문', 1.0)],
#  [('그', 1.0), ('라인', 1.0), ('밥집', 1.0)],
#  [('개판이네', 1.0), ('학교', 1.0)],
#  [('혹시', 1.0), ('락원이', 1.0), ('아니제', 1.0), ('지각하는거', 1.0)],
#  [('와이', 1.0)],
#  [('같이', 1.0),
#   ('오늘', 1.0),
#   ('하나', 1.0),
#   ('락원이가', 1.0),
#   ('둘', 1.0),
#   ('중에', 1.0),
#   ('공부하는거', 1.0),
#   ('구글', 1.0),
#   ('미트로', 1.0),
#   ('병원가거나', 1.0),
#   ('아니면', 1.0),
#   ('하자는데', 1.0)],
#  [('더', 1.0), ('니한테', 1.0), ('어느게', 1.0), ('좋노', 1.0)],
#  [('뭐임', 1.0), ('미트는', 1.0)],
#  [('줌이랑', 1.0)],
#  [('거임', 1.0), ('똑같은', 1.0)],
#  [('다', 1.0), ('난', 1.0), ('둘', 1.0), ('굳', 1.0)],
#  [('더', 1.0),
#   ('그럼', 1.0),
#   ('조금', 1.0),
#   ('락원이가', 1.0),
#   ('가자', 1.0),
#   ('좋아하는걸로', 1.0)],
#  [('난', 1.0), ('집에서', 1.0)],
#  [('집에서', 1.0), ('미트', 1.0)],
#  [('오늘', 1.0),
#   ('진짜', 1.0),
#   ('3시간동안', 1.0),
#   ('누른다', 1.0),
#   ('라임빌에서', 1.0),
#   ('벨', 1.0),
#   ('안들으면', 1.0),
#   ('양보했는데', 1.0),
#   ('이정도', 1.0)],
#  [('이거는', 1.0), ('강요지', 1.0), ('아니라', 1.0), ('양보가', 1.0)],
#  [('배드민턴', 1.0),
#   ('락원이', 1.0),
#   ('끝나면', 1.0),
#   ('끝나고', 1.0),
#   ('연락', 1.0),
#   ('줘', 1.0),
#   ('헬쓰', 1.0)],
#  [('이미', 1.0), ('끝났지', 1.0), ('헬스는', 1.0)],
#  [('락원아', 1.0), ('진짜', 1.0)],
#  [('락원아', 1.0), ('배드민턴', 1.0), ('혹시', 1.0)],
#  [('채', 1.0), ('만들어서', 1.0), ('치냐', 1.0)],
#  [('배드민턴', 1.0), ('밥이신갑네', 1.0)],
#  [('또', 1.0), ('가서', 1.0), ('끼부리나보지', 1.0), ('돌싱아줌마들한테', 1.0)],
#  [('우리', 1.0), ('꺄르륵', 1.0), ('락원학생', 1.0), ('엉덩이봐', 1.0), ('튼실하네', 1.0)],
#  [('응디', 1.0), ('한번', 1.0), ('흔들어봐라', 1.0)],
#  [('김태환', 1.0), ('수학', 1.0), ('17', 1.0)],
#  [('존나', 1.0), ('정없네', 1.0)],
#  [('수학과', 1.0), ('그런거없나', 1.0), ('에타', 1.0)],
#  [('그니까', 1.0)],
#  [('나처럼', 1.0)],
#  [('17김태환형', 1.0)],
#  [('어떰', 1.0)],
#  [('더', 1.0), ('닌', 1.0), ('없어', 1.0)],
#  [('난', 1.0), ('이틀딱', 1.0)],
#  [('이렇게', 1.0), ('저장해줬는데', 1.0)],
#  [('애정넘치네', 1.0)],
#  [('나도', 1.0), ('수정함', 1.0)],
#  [('했음', 1.0), ('김일페', 1.0), ('로', 1.0)],
#  [('없다', 1.0), ('임팩트가', 1.0)],
#  [('더', 1.0), ('해줘', 1.0), ('강한거로', 1.0)],
#  [('볼자노무현', 1.0)],
#  [('이런거', 1.0)],
#  [('난', 1.0), ('김태환', 1.0), ('17', 1.0)],
#  [('내가', 1.0), ('낫네', 1.0)],
#  [('니가', 1.0), ('제일', 1.0), ('낫네', 1.0), ('현재까진', 1.0)],
#  [('나도저거함', 1.0)],
#  [('나', 1.0),
#   ('15', 1.0),
#   ('김락원', 1.0),
#   ('형', 1.0),
#   ('미트', 1.0),
#   ('링크', 1.0),
#   ('보내줄게', 1.0),
#   ('출근해서', 1.0)],
#  [('돼', 1.0), ('안보내줘도', 1.0)],
#  [('보내주고', 1.0), ('후회해', 1.0)],
#  [('일단보내줘', 1.0)],
#  [('미방', 1.0), ('있는사람', 1.0), ('한국어책', 1.0)],
#  [('저녁', 1.0)],
#  [('다', 1.0), ('방금', 1.0), ('먹음', 1.0)],
#  [('에', 1.0)],
#  [('개빨리', 1.0), ('먹노', 1.0)],
#  [('점심', 1.0), ('일찍', 1.0), ('먹었더니', 1.0), ('배고프네', 1.0)],
#  [('약하노', 1.0)],
#  [('몇시까지', 1.0), ('하노', 1.0)],
#  [('10시', 1.0), ('50분', 1.0)],
#  [('내일', 1.0), ('병원', 1.0)],
#  [('락원이도', 1.0), ('온대', 1.0)],
#  [('난', 1.0), ('안가지', 1.0)],
#  [('이샛기는', 1.0)],
#  [('이럴떄만', 1.0)],
#  [('답장이', 1.0), ('빠르네', 1.0)],
#  [('내일', 1.0), ('알바임', 1.0)],
#  [('진짜', 1.0), ('락원인', 1.0)],
#  [('너무', 1.0), ('어메이징한데', 1.0)],
#  [('속도봐라1', 1.0)],
#  [('1', 1.0)],
#  [('아니', 1.0), ('태환이', 1.0)],
#  [('오늘', 1.0), ('락원이', 1.0), ('됐으면서도', 1.0), ('약속', 1.0), ('취소', 1.0)],
#  [('우리한테', 1.0), ('없이', 1.0), ('일언반구', 1.0)],
#  [('운동하러', 1.0), ('또', 1.0), ('쳐갔다는데', 1.0)],
#  [('지금', 1.0),
#   ('니가', 1.0),
#   ('나', 1.0),
#   ('좀', 1.0),
#   ('교육', 1.0),
#   ('못하겠음;;;', 1.0),
#   ('통화를', 1.0),
#   ('혈압올라서', 1.0)],
#  [('아니라', 1.0), ('미뤄진거지', 1.0), ('취소가', 1.0)],
#  [('락원이', 1.0), ('이제', 1.0), ('막나가겠다는거야', 1.0)],
#  [('너무', 1.0), ('실망인데', 1.0)],
#  [('아', 1.0), ('님스', 1.0), ('떨어짐', 1.0)],
#  [('락', 1.0), ('탈', 1.0), ('해버렸습니다', 1.0)],
#  [('이건', 1.0), ('락원이가', 1.0), ('쏴야지', 1.0), ('위로겸', 1.0), ('한턱', 1.0)],
#  [('위로만', 1.0), ('해줄게', 1.0)],
#  [('내가', 1.0),
#   ('넌', 1.0),
#   ('사', 1.0),
#   ('그냥', 1.0),
#   ('밥으로', 1.0),
#   ('위로는', 1.0),
#   ('자기', 1.0),
#   ('잘해서', 1.0),
#   ('훨씬', 1.0)],
#  [('내게', 1.0), ('밥', 1.0), ('사는것을', 1.0), ('허락하지', 1.0)],
#  [('난', 1.0), ('거절할게', 1.0)],
#  [('허락해', 1.0)],
#  [('고토', 1.0), ('비쁠', 1.0)],
#  [('만족한다', 1.0)],
#  [('고토', 1.0), ('비쁠은', 1.0), ('잘한거지', 1.0)],
#  [('아', 1.0),
#   ('내가', 1.0),
#   ('함', 1.0),
#   ('락', 1.0),
#   ('살게', 1.0),
#   ('어이스크림', 1.0)],
#  [('동현이', 1.0), ('까라', 1.0), ('빨리', 1.0)],
#  [('벡해', 1.0), ('비쁠', 1.0)],
#  [('오늘', 1.0), ('사줘라', 1.0)],
#  [('안됨', 1.0), ('이번주는', 1.0)],
#  [('집감', 1.0)],
#  [('풀약', 1.0)],
#  [('근데', 1.0), ('아니', 1.0), ('이걸', 1.0), ('락', 1.0), ('동한테', 1.0)],
#  [('고기', 1.0), ('못얻어먹네', 1.0)],
#  [('뭐', 1.0), ('나왔는데', 1.0), ('고토', 1.0)],
#  [('비쁠', 1.0)],
#  [('개조진게', 1.0), ('기말', 1.0), ('큰거같은데', 1.0)],
#  [('그래도', 1.0), ('낫네', 1.0), ('A0로', 1.0), ('먹는거보다는', 1.0), ('못얻어', 1.0)],
#  [('못보고', 1.0), ('전체평점도', 1.0)],
#  [('왜', 1.0),
#   ('내가', 1.0),
#   ('하', 1.0),
#   ('고토', 1.0),
#   ('교양을', 1.0),
#   ('끝나서', 1.0),
#   ('다행임', 1.0),
#   ('생각들다가도', 1.0),
#   ('쳐들었지', 1.0),
#   ('학기중에', 1.0)],
#  [('그럼', 1.0), ('다', 1.0), ('교필은', 1.0), ('들은거임', 1.0)],
#  [('교선까지', 1.0), ('끝남', 1.0), ('이번계절로', 1.0)],
#  [('다음학기', 1.0), ('6학점', 1.0), ('끝이다', 1.0)],
#  [('후', 1.0)],
#  [('다음학기', 1.0), ('대면이라던데', 1.0)],
#  [('재강', 1.0), ('피셜로', 1.0), ('호균', 1.0)],
#  [('하고', 1.0), ('같기도', 1.0), ('그런것', 1.0), ('뉴스보니깐', 1.0)],
#  [('아', 1.0), ('거지같네', 1.0)],
#  [('아', 1.0), ('어떡하냐', 1.0)],
#  [('진짜', 1.0), ('난', 1.0), ('없음', 1.0), ('대면', 1.0), ('자신이', 1.0)],
#  [('그니까', 1.0), ('가야되는데', 1.0), ('그시간에', 1.0), ('헬스', 1.0)],
#  [('완전창남인데', 1.0)],
#  [('하니깐', 1.0), ('창남이긴', 1.0), ('헬창도', 1.0)],
#  [('같이', 1.0), ('태환이형', 1.0), ('14시', 1.0), ('근무', 1.0), ('수욜', 1.0)],
#  [('나', 1.0), ('계절수업있어서', 1.0), ('과외랑', 1.0), ('멘토링이랑', 1.0), ('오후시간대', 1.0)],
#  [('912시로', 1.0), ('월', 1.0), ('했는뎅', 1.0)],
#  [('동현이', 1.0), ('1등', 1.0), ('팽방', 1.0)],
#  [('개띄꺼운데', 1.0)],
#  [('왜', 1.0), ('나한텐', 1.0), ('안해주냐', 1.0), ('인사', 1.0)],
#  [('야', 1.0), ('허정훈', 1.0)],
#  [('생각났다', 1.0), ('아이디어', 1.0), ('지리는', 1.0)],
#  [('게임방식', 1.0),
#   ('롤', 1.0),
#   ('방식이나', 1.0),
#   ('이런걸로', 1.0),
#   ('채팅', 1.0),
#   ('플레이', 1.0)],
#  [('좀', 1.0), ('해줘', 1.0), ('분석', 1.0), ('잼민이', 1.0)],
#  [('갑자기', 1.0), ('씨발', 1.0), ('오바잖아', 1.0), ('학원가는건', 1.0)],
#  [('아닌지', 1.0), ('잼민이인지', 1.0)],
#  [('판단해달라는거', 1.0)],
#  [('게임이탈여부', 1.0), ('알고리즘', 1.0), ('예측', 1.0)],
#  [('있음', 1.0), ('이런건', 1.0)],
#  [('아니', 1.0), ('난', 1.0), ('아닌지를', 1.0), ('알고싶어', 1.0), ('잼민인인지', 1.0)],
#  [('그냥', 1.0), ('잼민이', 1.0), ('닷지하게', 1.0), ('많으면', 1.0), ('픽창에서', 1.0)],
#  [('쓰발', 1.0)],
#  [('잼민이뱃지', 1.0)],
#  [('이런거있음좋겧다', 1.0)]]

# %%
# Author Topic Model 실행
NUM_TOPICS = 4

if not os.path.exists("kakao(ATM)_model"):
    model = AuthorTopicModel(corpus=corpus, id2word=dictionary.id2token, num_topics=NUM_TOPICS, author2doc=author2doc, passes=100)
    model.save("kakao(ATM)_model")
else:
    model = AuthorTopicModel.load("kakao(ATM)_model")

# %%
# 학습 결과 확인하기
model.show_topic(1) # 1번째 토픽
# Out:
# [('난', 0.012260236931585794),
#  ('아', 0.011676997276547715),
#  ('락원이', 0.010431516849827774),
#  ('동현이', 0.005928134762841963),
#  ('오늘', 0.005294233510440971),
#  ('다', 0.005287299506846207),
#  ('내가', 0.005243276235309308),
#  ('근데', 0.004646346629371917),
#  ('나', 0.004085344852820157),
#  ('아니', 0.004019273777094868)]

# %%
model.show_topic(1, topn=20) # top20
# Out:
# [('난', 0.012260236931585794),
#  ('아', 0.011676997276547715),
#  ('락원이', 0.010431516849827774),
#  ('동현이', 0.005928134762841963),
#  ('오늘', 0.005294233510440971),
#  ('다', 0.005287299506846207),
#  ('내가', 0.005243276235309308),
#  ('근데', 0.004646346629371917),
#  ('나', 0.004085344852820157),
#  ('아니', 0.004019273777094868),
#  ('진짜', 0.004006107460260246),
#  ('더', 0.004005512804978402),
#  ('내일', 0.0034142604828852276),
#  ('그럼', 0.003364904612905689),
#  ('이걸', 0.003364637952624334),
#  ('니', 0.002730084928202692),
#  ('좀', 0.002724732961971116),
#  ('락', 0.002723984236604207),
#  ('너가', 0.0027237221128403382),
#  ('이거', 0.0027237196641392526)]
